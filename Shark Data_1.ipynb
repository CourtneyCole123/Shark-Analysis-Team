# %%
# imports
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress
import json

# %%
# create base url
base_url = 'https://public.opendatasoft.com/api/explore/v2.1/catalog/datasets/global-shark-attack/records?limit=100'

# %%
# read base_url
requests.get(base_url)
# Out:
# <Response [200]>

# %%
# create list of #s for offet
total_count = requests.get(base_url).json()['total_count']

# %%
# hold the data
all_of_the_data = []

# %%
# loop through offsets to combine data into one dataframe
for currentOffset in np.arange(0,total_count,100):
  # print(currentOffset)
  cur_data = requests.get(f'{base_url}&offset={currentOffset}').json()['results']
  all_of_the_data.extend(cur_data) #extend is like
  time.sleep(0.5)

# %%
# check number of data points total in list of offsets
len(all_of_the_data)
# Out:
# 6890

# %%
# create a dataframe from offset list
all_of_the_data_df = pd.DataFrame(all_of_the_data)
all_of_the_data_df
# Out:
#             date  year          type       country                area  \
# 0     2023-05-13  2023    Unprovoked     AUSTRALIA     South Australia
# 1     2023-04-29  2023    Unprovoked     AUSTRALIA   Western Australia
# 2     2022-10-07  2022    Unprovoked     AUSTRALIA  Western  Australia
# 3     2021-10-04  2021    Unprovoked           USA             Florida
# 4     2021-10-03  2021    Unprovoked           USA             Florida
# ...          ...   ...           ...           ...                 ...
# 6885        None  None  Sea Disaster        GREECE        Off Thessaly
# 6886        None  None    Unprovoked     INDONESIA       Riau Province
# 6887        None  None    Unprovoked          IRAQ              Basrah
# 6888        None  None    Unprovoked  SOUTH AFRICA       KwaZulu-Natal
# 6889        None  None    Unprovoked     AUSTRALIA   Western Australia
#
#                                                location  \
# 0                                              Elliston
# 1                                  Yallingup, Busselton
# 2                                          Port Hedland
# 3              Fort Pierce State Park, St. Lucie County
# 4                           Jensen Beach, Martin County
# ...                                                 ...
# 6885                                               None
# 6886  Natuna Islands, between Sumatra & Kalimantan i...
# 6887        Shatt-el Arab River near a small boat stand
# 6888                                             Durban
# 6889                                               None
#
#                                          activity                name sex  \
# 0                                         Surfing    Simon Baccanello   M
# 1                                        Swimming                male   M
# 2                                    Spearfishing         Robbie Peck   M
# 3                                         Surfing  Truman Van Patrick   M
# 4                                        Swimming                male   M
# ...                                           ...                 ...  ..
# 6885                    Shipwrecked Persian Fleet               males   M
# 6886                  Swimming near anchored ship   a ship's engineer   M
# 6887                                     Swimming                male   M
# 6888  Crew swimming alongside their anchored ship                male   M
# 6889                                 Pearl diving               Ahmun   M
#
#            age  ... fatal_y_n       time      species  \
# 0           46  ...         Y      10h10  White shark
# 1         None  ...         N      11h20     1m shark
# 2           38  ...         N      11h30   Bull shark
# 3         25.0  ...         N       None         None
# 4         None  ...         N      12h00         None
# ...        ...  ...       ...        ...          ...
# 6885      None  ...         Y       None         None
# 6886      None  ...         Y       None         None
# 6887  13 or 14  ...         Y  Afternoon   Bull shark
# 6888      None  ...         Y       None         None
# 6889      None  ...         Y       None         None
#
#                                  investigator_or_source  \
# 0                         B. Myatt & S. De Marchi, GSAF
# 1                         The West Austalian, 4/30/2023
# 2                                   ABC,net, 10/07/2022
# 3                       K. McMurray, TrackingSharks.com
# 4                                      CBS12, 10/3/2021
# ...                                                 ...
# 6885                         Herodotus (485 - 425 B.C.)
# 6886       C.H. Townsend, p. 172; V.M. Coppleson, p.258
# 6887                       B.W. Coad & L.A.J. Al-Hassan
# 6888  Captain A. Anderson,  Natal Mercury, 12/31/192...
# 6889              H. Taunton; N. Bartlett,  pp. 233-234
#
#                                 pdf  \
# 0                              None
# 1                              None
# 2                              None
# 3         2021.10.04-VanPatrick.pdf
# 4     2021.10.03.b-JensenBeach.pdf1
# ...                             ...
# 6885         493BC-PersianFleet.pdf
# 6886      ND-0054-NatunaIslands.pdf
# 6887      ND-0038-Shatt-al-Arab.pdf
# 6888     ND-0017-alongside-ship.pdf
# 6889              ND-0004-Ahmun.pdf
#
#                                            href_formula  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6885  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6886  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6887  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6888  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6889  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href         case_number  \
# 0                                                  None                None
# 1                                                  None                None
# 2                                                  None                None
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...          2021.10.04
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...        2021.10.03.b
# ...                                                 ...                 ...
# 6885  http://sharkattackfile.net/spreadsheets/pdf_di...  493BC-PersianFleet
# 6886  http://sharkattackfile.net/spreadsheets/pdf_di...             ND.0054
# 6887  http://sharkattackfile.net/spreadsheets/pdf_di...             ND.0038
# 6888  http://sharkattackfile.net/spreadsheets/pdf_di...             ND.0017
# 6889  http://sharkattackfile.net/spreadsheets/pdf_di...             ND.0004
#
#       case_number0 original_order
# 0             None           None
# 1             None           None
# 2             None           None
# 3       2021.10.04           6711
# 4     2021.10.04.b           6710
# ...            ...            ...
# 6885         493BC            128
# 6886       ND.0054             52
# 6887       ND.0038             38
# 6888       ND.0017             18
# 6889       ND.0004              5
#
# [6890 rows x 21 columns]

# %%
# Changed all None to nan and then dropped all nans
new_data_df = all_of_the_data_df.replace(to_replace='None', value=np.nan).dropna()
new_data_df
# Out:
#             date  year          type           country  \
# 6     2021-05-03  2021    Unprovoked               USA
# 10    2020-10-31  2020    Unprovoked               USA
# 13    2020-02-22  2020    Unprovoked       NEW ZEALAND
# 19    2019-01-29  2019       Invalid       NEW ZEALAND
# 22    2018-06-25  2018    Watercraft               USA
# ...          ...   ...           ...               ...
# 6816  1958-07-04  1958  Sea Disaster     PACIFIC OCEAN
# 6817  1958-01-19  1958    Unprovoked         AUSTRALIA
# 6818  1957-04-13  1957    Unprovoked         AUSTRALIA
# 6824  1955-11-16  1955    Unprovoked  PAPUA NEW GUINEA
# 6844  1936-02-04  1936    Unprovoked         AUSTRALIA
#
#                               area  \
# 6                           Hawaii
# 10                         Florida
# 13                    North Island
# 19                    South Island
# 22                      California
# ...                            ...
# 6816  Between Hawaii & Wake Island
# 6817               New South Wales
# 6818                 Torres Strait
# 6824              Central Province
# 6844               New South Wales
#
#                                                location  \
# 6                               Marine Corps Base, Oahu
# 10                                         Ormond Beach
# 13                                        Pauanui Beach
# 19                                          Oreti Beach
# 22                          Oceanside, San Diego County
# ...                                                 ...
# 6816                    600 miles northwest of Honolulu
# 6817                                    Brunswick Heads
# 6818                Thursday Island Harbour, Queensland
# 6824  Kalautu Village, Baibara at the mouth of Oibad...
# 6844                                South Steyne, Manly
#
#                                                activity  \
# 6                                               Surfing
# 10                                             Swimming
# 13                                              Surfing
# 19                                      Boogie boarding
# 22                                             Paddling
# ...                                                 ...
# 6816  U.S. Airforce C124 enroute from Hickham Air Ba...
# 6817                                       Body surfing
# 6818       Swimming between  anchored  pearling luggers
# 6824                                           Swimming
# 6844                                           Swimming
#
#                                name sex   age  ... fatal_y_n     time  \
# 6                 Parker Blanchette   M  14.0  ...         N    16h00
# 10                    Jordan Hooper   M  17.0  ...         N    16h00
# 13                     Nick Minogue   M  60.0  ...         N    11h30
# 19                           female   F  17.0  ...         N  Evening
# 22                      Julie Wolfe   F  57.0  ...         N    18h00
# ...                             ...  ..   ...  ...       ...      ...
# 6816  Captain Jonathan Brown, pilot   M  31.0  ...         N    10h25
# 6817                Brian Henderson   M  14.0  ...         N    16h30
# 6818                 Tuisafua Nomoa   M  22.0  ...         N    14h00
# 6824                       Niu Bodu   M   8.0  ...         N    18h00
# 6844                    David Paton   M  14.0  ...         Y    15h00
#
#                                                 species  \
# 6                                          5.5 ft shark
# 10                             Blacktip shark, 6' to 7'
# 13                                          White shark
# 19    Reported as shark bite but injury caused by st...
# 22                                          White shark
# ...                                                 ...
# 6816               Sharks averaged 1.8 m [6'] in length
# 6817                                           6' shark
# 6818  Shark seen feeding on turtle scraps thrown ove...
# 6824                                    Wobbegong shark
# 6844                                        White shark
#
#                                  investigator_or_source  \
# 6                       K. McMurray, TrackingSharks.com
# 10                      K. McMurray, TrackingSharks.com
# 13                                 NZ Herald, 2/22/2020
# 19                      K. McMurray, TrackingSharks.com
# 22                                     R. Collier, GSAF
# ...                                                 ...
# 6816  Evening Star (Washington D.C.), 7/7/1958, p. A...
# 6817                       V.M. Coppleson (1962), p.245
# 6818  J.W. Robinson; V.M. Coppleson (1958), p.245; J...
# 6824             J. G. Davis; A.M. Rapson, pp.143 & 148
# 6844  V.M. Coppleson (1958), pp.67 & 234; A. Sharpe,...
#
#                              pdf  \
# 6          2021.05.01-Hawaii.pdf
# 10    2020.10.31-OrmondBeach.pdf
# 13        2020.02.22-Minogue.pdf
# 19             2019.01.29-NZ.pdf
# 22          2018.06.25-Wolfe.pdf
# ...                          ...
# 6816      1958.07.04.a-Brown.pdf
# 6817    1958.01.19-Henderson.pdf
# 6818        1957.04.13-Nomoa.pdf
# 6824      1955.11.16-NiuBodu.pdf
# 6844        1936.02.04-Paton.pdf
#
#                                            href_formula  \
# 6     http://sharkattackfile.net/spreadsheets/pdf_di...
# 10    http://sharkattackfile.net/spreadsheets/pdf_di...
# 13    http://sharkattackfile.net/spreadsheets/pdf_di...
# 19    http://sharkattackfile.net/spreadsheets/pdf_di...
# 22    http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6816  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6817  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6818  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6824  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6844  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href   case_number  \
# 6     http://sharkattackfile.net/spreadsheets/pdf_di...    2021.05.03
# 10    http://sharkattackfile.net/spreadsheets/pdf_di...    2020.10.31
# 13    http://sharkattackfile.net/spreadsheets/pdf_di...    2020.02.22
# 19    http://sharkattackfile.net/spreadsheets/pdf_di...    2019.01.29
# 22    http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# ...                                                 ...           ...
# 6816  http://sharkattackfile.net/spreadsheets/pdf_di...  1958.07.04.a
# 6817  http://sharkattackfile.net/spreadsheets/pdf_di...    1958.01.19
# 6818  http://sharkattackfile.net/spreadsheets/pdf_di...    1957.04.13
# 6824  http://sharkattackfile.net/spreadsheets/pdf_di...    1955.11.16
# 6844  http://sharkattackfile.net/spreadsheets/pdf_di...    1936.02.04
#
#       case_number0 original_order
# 6       2021.05.03           6656
# 10      2020.10.31           6604
# 13      2020.02.22           6527
# 19      2019.01.29           6405
# 22      2018.06.25           6335
# ...            ...            ...
# 6816  1958.07.04.a           2164
# 6817    1958.01.19           2146
# 6818    1957.04.13           2112
# 6824    1955.11.16           2040
# 6844    1936.02.04           1424
#
# [1622 rows x 21 columns]

# %%
# checked data types
new_data_df.dtypes
# Out:
# date                      object
# year                      object
# type                      object
# country                   object
# area                      object
# location                  object
# activity                  object
# name                      object
# sex                       object
# age                       object
# injury                    object
# fatal_y_n                 object
# time                      object
# species                   object
# investigator_or_source    object
# pdf                       object
# href_formula              object
# href                      object
# case_number               object
# case_number0              object
# original_order            object
# dtype: object

# %%
# change age from object to number
new_data_df['age'] = pd.to_numeric(all_of_the_data_df['age'], errors='coerce')
new_data_df
# Out:
#             date  year          type           country  \
# 6     2021-05-03  2021    Unprovoked               USA
# 10    2020-10-31  2020    Unprovoked               USA
# 13    2020-02-22  2020    Unprovoked       NEW ZEALAND
# 19    2019-01-29  2019       Invalid       NEW ZEALAND
# 22    2018-06-25  2018    Watercraft               USA
# ...          ...   ...           ...               ...
# 6816  1958-07-04  1958  Sea Disaster     PACIFIC OCEAN
# 6817  1958-01-19  1958    Unprovoked         AUSTRALIA
# 6818  1957-04-13  1957    Unprovoked         AUSTRALIA
# 6824  1955-11-16  1955    Unprovoked  PAPUA NEW GUINEA
# 6844  1936-02-04  1936    Unprovoked         AUSTRALIA
#
#                               area  \
# 6                           Hawaii
# 10                         Florida
# 13                    North Island
# 19                    South Island
# 22                      California
# ...                            ...
# 6816  Between Hawaii & Wake Island
# 6817               New South Wales
# 6818                 Torres Strait
# 6824              Central Province
# 6844               New South Wales
#
#                                                location  \
# 6                               Marine Corps Base, Oahu
# 10                                         Ormond Beach
# 13                                        Pauanui Beach
# 19                                          Oreti Beach
# 22                          Oceanside, San Diego County
# ...                                                 ...
# 6816                    600 miles northwest of Honolulu
# 6817                                    Brunswick Heads
# 6818                Thursday Island Harbour, Queensland
# 6824  Kalautu Village, Baibara at the mouth of Oibad...
# 6844                                South Steyne, Manly
#
#                                                activity  \
# 6                                               Surfing
# 10                                             Swimming
# 13                                              Surfing
# 19                                      Boogie boarding
# 22                                             Paddling
# ...                                                 ...
# 6816  U.S. Airforce C124 enroute from Hickham Air Ba...
# 6817                                       Body surfing
# 6818       Swimming between  anchored  pearling luggers
# 6824                                           Swimming
# 6844                                           Swimming
#
#                                name sex   age  ... fatal_y_n     time  \
# 6                 Parker Blanchette   M  14.0  ...         N    16h00
# 10                    Jordan Hooper   M  17.0  ...         N    16h00
# 13                     Nick Minogue   M  60.0  ...         N    11h30
# 19                           female   F  17.0  ...         N  Evening
# 22                      Julie Wolfe   F  57.0  ...         N    18h00
# ...                             ...  ..   ...  ...       ...      ...
# 6816  Captain Jonathan Brown, pilot   M  31.0  ...         N    10h25
# 6817                Brian Henderson   M  14.0  ...         N    16h30
# 6818                 Tuisafua Nomoa   M  22.0  ...         N    14h00
# 6824                       Niu Bodu   M   8.0  ...         N    18h00
# 6844                    David Paton   M  14.0  ...         Y    15h00
#
#                                                 species  \
# 6                                          5.5 ft shark
# 10                             Blacktip shark, 6' to 7'
# 13                                          White shark
# 19    Reported as shark bite but injury caused by st...
# 22                                          White shark
# ...                                                 ...
# 6816               Sharks averaged 1.8 m [6'] in length
# 6817                                           6' shark
# 6818  Shark seen feeding on turtle scraps thrown ove...
# 6824                                    Wobbegong shark
# 6844                                        White shark
#
#                                  investigator_or_source  \
# 6                       K. McMurray, TrackingSharks.com
# 10                      K. McMurray, TrackingSharks.com
# 13                                 NZ Herald, 2/22/2020
# 19                      K. McMurray, TrackingSharks.com
# 22                                     R. Collier, GSAF
# ...                                                 ...
# 6816  Evening Star (Washington D.C.), 7/7/1958, p. A...
# 6817                       V.M. Coppleson (1962), p.245
# 6818  J.W. Robinson; V.M. Coppleson (1958), p.245; J...
# 6824             J. G. Davis; A.M. Rapson, pp.143 & 148
# 6844  V.M. Coppleson (1958), pp.67 & 234; A. Sharpe,...
#
#                              pdf  \
# 6          2021.05.01-Hawaii.pdf
# 10    2020.10.31-OrmondBeach.pdf
# 13        2020.02.22-Minogue.pdf
# 19             2019.01.29-NZ.pdf
# 22          2018.06.25-Wolfe.pdf
# ...                          ...
# 6816      1958.07.04.a-Brown.pdf
# 6817    1958.01.19-Henderson.pdf
# 6818        1957.04.13-Nomoa.pdf
# 6824      1955.11.16-NiuBodu.pdf
# 6844        1936.02.04-Paton.pdf
#
#                                            href_formula  \
# 6     http://sharkattackfile.net/spreadsheets/pdf_di...
# 10    http://sharkattackfile.net/spreadsheets/pdf_di...
# 13    http://sharkattackfile.net/spreadsheets/pdf_di...
# 19    http://sharkattackfile.net/spreadsheets/pdf_di...
# 22    http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6816  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6817  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6818  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6824  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6844  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href   case_number  \
# 6     http://sharkattackfile.net/spreadsheets/pdf_di...    2021.05.03
# 10    http://sharkattackfile.net/spreadsheets/pdf_di...    2020.10.31
# 13    http://sharkattackfile.net/spreadsheets/pdf_di...    2020.02.22
# 19    http://sharkattackfile.net/spreadsheets/pdf_di...    2019.01.29
# 22    http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# ...                                                 ...           ...
# 6816  http://sharkattackfile.net/spreadsheets/pdf_di...  1958.07.04.a
# 6817  http://sharkattackfile.net/spreadsheets/pdf_di...    1958.01.19
# 6818  http://sharkattackfile.net/spreadsheets/pdf_di...    1957.04.13
# 6824  http://sharkattackfile.net/spreadsheets/pdf_di...    1955.11.16
# 6844  http://sharkattackfile.net/spreadsheets/pdf_di...    1936.02.04
#
#       case_number0 original_order
# 6       2021.05.03           6656
# 10      2020.10.31           6604
# 13      2020.02.22           6527
# 19      2019.01.29           6405
# 22      2018.06.25           6335
# ...            ...            ...
# 6816  1958.07.04.a           2164
# 6817    1958.01.19           2146
# 6818    1957.04.13           2112
# 6824    1955.11.16           2040
# 6844    1936.02.04           1424
#
# [1622 rows x 21 columns]

# %%
# change age from number to integer
new_data_df['age'] = new_data_df['age'].astype('Int64')
new_data_df
# Out:
#             date  year          type           country  \
# 6     2021-05-03  2021    Unprovoked               USA
# 10    2020-10-31  2020    Unprovoked               USA
# 13    2020-02-22  2020    Unprovoked       NEW ZEALAND
# 19    2019-01-29  2019       Invalid       NEW ZEALAND
# 22    2018-06-25  2018    Watercraft               USA
# ...          ...   ...           ...               ...
# 6816  1958-07-04  1958  Sea Disaster     PACIFIC OCEAN
# 6817  1958-01-19  1958    Unprovoked         AUSTRALIA
# 6818  1957-04-13  1957    Unprovoked         AUSTRALIA
# 6824  1955-11-16  1955    Unprovoked  PAPUA NEW GUINEA
# 6844  1936-02-04  1936    Unprovoked         AUSTRALIA
#
#                               area  \
# 6                           Hawaii
# 10                         Florida
# 13                    North Island
# 19                    South Island
# 22                      California
# ...                            ...
# 6816  Between Hawaii & Wake Island
# 6817               New South Wales
# 6818                 Torres Strait
# 6824              Central Province
# 6844               New South Wales
#
#                                                location  \
# 6                               Marine Corps Base, Oahu
# 10                                         Ormond Beach
# 13                                        Pauanui Beach
# 19                                          Oreti Beach
# 22                          Oceanside, San Diego County
# ...                                                 ...
# 6816                    600 miles northwest of Honolulu
# 6817                                    Brunswick Heads
# 6818                Thursday Island Harbour, Queensland
# 6824  Kalautu Village, Baibara at the mouth of Oibad...
# 6844                                South Steyne, Manly
#
#                                                activity  \
# 6                                               Surfing
# 10                                             Swimming
# 13                                              Surfing
# 19                                      Boogie boarding
# 22                                             Paddling
# ...                                                 ...
# 6816  U.S. Airforce C124 enroute from Hickham Air Ba...
# 6817                                       Body surfing
# 6818       Swimming between  anchored  pearling luggers
# 6824                                           Swimming
# 6844                                           Swimming
#
#                                name sex  age  ... fatal_y_n     time  \
# 6                 Parker Blanchette   M   14  ...         N    16h00
# 10                    Jordan Hooper   M   17  ...         N    16h00
# 13                     Nick Minogue   M   60  ...         N    11h30
# 19                           female   F   17  ...         N  Evening
# 22                      Julie Wolfe   F   57  ...         N    18h00
# ...                             ...  ..  ...  ...       ...      ...
# 6816  Captain Jonathan Brown, pilot   M   31  ...         N    10h25
# 6817                Brian Henderson   M   14  ...         N    16h30
# 6818                 Tuisafua Nomoa   M   22  ...         N    14h00
# 6824                       Niu Bodu   M    8  ...         N    18h00
# 6844                    David Paton   M   14  ...         Y    15h00
#
#                                                 species  \
# 6                                          5.5 ft shark
# 10                             Blacktip shark, 6' to 7'
# 13                                          White shark
# 19    Reported as shark bite but injury caused by st...
# 22                                          White shark
# ...                                                 ...
# 6816               Sharks averaged 1.8 m [6'] in length
# 6817                                           6' shark
# 6818  Shark seen feeding on turtle scraps thrown ove...
# 6824                                    Wobbegong shark
# 6844                                        White shark
#
#                                  investigator_or_source  \
# 6                       K. McMurray, TrackingSharks.com
# 10                      K. McMurray, TrackingSharks.com
# 13                                 NZ Herald, 2/22/2020
# 19                      K. McMurray, TrackingSharks.com
# 22                                     R. Collier, GSAF
# ...                                                 ...
# 6816  Evening Star (Washington D.C.), 7/7/1958, p. A...
# 6817                       V.M. Coppleson (1962), p.245
# 6818  J.W. Robinson; V.M. Coppleson (1958), p.245; J...
# 6824             J. G. Davis; A.M. Rapson, pp.143 & 148
# 6844  V.M. Coppleson (1958), pp.67 & 234; A. Sharpe,...
#
#                              pdf  \
# 6          2021.05.01-Hawaii.pdf
# 10    2020.10.31-OrmondBeach.pdf
# 13        2020.02.22-Minogue.pdf
# 19             2019.01.29-NZ.pdf
# 22          2018.06.25-Wolfe.pdf
# ...                          ...
# 6816      1958.07.04.a-Brown.pdf
# 6817    1958.01.19-Henderson.pdf
# 6818        1957.04.13-Nomoa.pdf
# 6824      1955.11.16-NiuBodu.pdf
# 6844        1936.02.04-Paton.pdf
#
#                                            href_formula  \
# 6     http://sharkattackfile.net/spreadsheets/pdf_di...
# 10    http://sharkattackfile.net/spreadsheets/pdf_di...
# 13    http://sharkattackfile.net/spreadsheets/pdf_di...
# 19    http://sharkattackfile.net/spreadsheets/pdf_di...
# 22    http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6816  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6817  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6818  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6824  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6844  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href   case_number  \
# 6     http://sharkattackfile.net/spreadsheets/pdf_di...    2021.05.03
# 10    http://sharkattackfile.net/spreadsheets/pdf_di...    2020.10.31
# 13    http://sharkattackfile.net/spreadsheets/pdf_di...    2020.02.22
# 19    http://sharkattackfile.net/spreadsheets/pdf_di...    2019.01.29
# 22    http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# ...                                                 ...           ...
# 6816  http://sharkattackfile.net/spreadsheets/pdf_di...  1958.07.04.a
# 6817  http://sharkattackfile.net/spreadsheets/pdf_di...    1958.01.19
# 6818  http://sharkattackfile.net/spreadsheets/pdf_di...    1957.04.13
# 6824  http://sharkattackfile.net/spreadsheets/pdf_di...    1955.11.16
# 6844  http://sharkattackfile.net/spreadsheets/pdf_di...    1936.02.04
#
#       case_number0 original_order
# 6       2021.05.03           6656
# 10      2020.10.31           6604
# 13      2020.02.22           6527
# 19      2019.01.29           6405
# 22      2018.06.25           6335
# ...            ...            ...
# 6816  1958.07.04.a           2164
# 6817    1958.01.19           2146
# 6818    1957.04.13           2112
# 6824    1955.11.16           2040
# 6844    1936.02.04           1424
#
# [1622 rows x 21 columns]

# %%
# deleted unnecessary column
del new_data_df['investigator_or_source']

# %%
# deleted unnecessary column
del new_data_df['pdf']

# %%
# deleted unnecessary column
del new_data_df['href_formula']

# %%
# deleted unnecessary column
del new_data_df['href']

# %%
# deleted unnecessary column
del new_data_df['case_number']

# %%
# deleted unnecessary column
del new_data_df['case_number0']

# %%
# deleted unnecessary column
del new_data_df['original_order']

# %%
# reprint dataframe with removed columns
new_data_df
# Out:
#             date  year          type           country  \
# 6     2021-05-03  2021    Unprovoked               USA
# 10    2020-10-31  2020    Unprovoked               USA
# 13    2020-02-22  2020    Unprovoked       NEW ZEALAND
# 19    2019-01-29  2019       Invalid       NEW ZEALAND
# 22    2018-06-25  2018    Watercraft               USA
# ...          ...   ...           ...               ...
# 6816  1958-07-04  1958  Sea Disaster     PACIFIC OCEAN
# 6817  1958-01-19  1958    Unprovoked         AUSTRALIA
# 6818  1957-04-13  1957    Unprovoked         AUSTRALIA
# 6824  1955-11-16  1955    Unprovoked  PAPUA NEW GUINEA
# 6844  1936-02-04  1936    Unprovoked         AUSTRALIA
#
#                               area  \
# 6                           Hawaii
# 10                         Florida
# 13                    North Island
# 19                    South Island
# 22                      California
# ...                            ...
# 6816  Between Hawaii & Wake Island
# 6817               New South Wales
# 6818                 Torres Strait
# 6824              Central Province
# 6844               New South Wales
#
#                                                location  \
# 6                               Marine Corps Base, Oahu
# 10                                         Ormond Beach
# 13                                        Pauanui Beach
# 19                                          Oreti Beach
# 22                          Oceanside, San Diego County
# ...                                                 ...
# 6816                    600 miles northwest of Honolulu
# 6817                                    Brunswick Heads
# 6818                Thursday Island Harbour, Queensland
# 6824  Kalautu Village, Baibara at the mouth of Oibad...
# 6844                                South Steyne, Manly
#
#                                                activity  \
# 6                                               Surfing
# 10                                             Swimming
# 13                                              Surfing
# 19                                      Boogie boarding
# 22                                             Paddling
# ...                                                 ...
# 6816  U.S. Airforce C124 enroute from Hickham Air Ba...
# 6817                                       Body surfing
# 6818       Swimming between  anchored  pearling luggers
# 6824                                           Swimming
# 6844                                           Swimming
#
#                                name sex  age  \
# 6                 Parker Blanchette   M   14
# 10                    Jordan Hooper   M   17
# 13                     Nick Minogue   M   60
# 19                           female   F   17
# 22                      Julie Wolfe   F   57
# ...                             ...  ..  ...
# 6816  Captain Jonathan Brown, pilot   M   31
# 6817                Brian Henderson   M   14
# 6818                 Tuisafua Nomoa   M   22
# 6824                       Niu Bodu   M    8
# 6844                    David Paton   M   14
#
#                                                  injury fatal_y_n     time  \
# 6                          Lacerations to shin and calf         N    16h00
# 10                                       Minor injuries         N    16h00
# 13                       Minor injury, surfboard bitten         N    11h30
# 19                                        Gash to thigh         N  Evening
# 22    No injury to occupant, outrigger canoe and pad...         N    18h00
# ...                                                 ...       ...      ...
# 6816                               Left shoulder bitten         N    10h25
# 6817      Laceration to left ankle, heel and little toe         N    16h30
# 6818              Left arm bitten, surgically amputated         N    14h00
# 6824                                 Right thigh bitten         N    18h00
# 6844  FATAL, taken by shark, body not recovered. Twe...         Y    15h00
#
#                                                 species
# 6                                          5.5 ft shark
# 10                             Blacktip shark, 6' to 7'
# 13                                          White shark
# 19    Reported as shark bite but injury caused by st...
# 22                                          White shark
# ...                                                 ...
# 6816               Sharks averaged 1.8 m [6'] in length
# 6817                                           6' shark
# 6818  Shark seen feeding on turtle scraps thrown ove...
# 6824                                    Wobbegong shark
# 6844                                        White shark
#
# [1622 rows x 14 columns]

# %%
# split text to columns on species and rename columns 
fixed_data_df = new_data_df.join(
     new_data_df['species'].str.split(',', expand=True).rename(
         columns={0:'Species_1', 1:'Species_2', 2:'Species_3',3:'Species_4'}
     )
 )

# %%
fixed_data_df
# Out:
#             date  year          type           country  \
# 6     2021-05-03  2021    Unprovoked               USA
# 10    2020-10-31  2020    Unprovoked               USA
# 13    2020-02-22  2020    Unprovoked       NEW ZEALAND
# 19    2019-01-29  2019       Invalid       NEW ZEALAND
# 22    2018-06-25  2018    Watercraft               USA
# ...          ...   ...           ...               ...
# 6816  1958-07-04  1958  Sea Disaster     PACIFIC OCEAN
# 6817  1958-01-19  1958    Unprovoked         AUSTRALIA
# 6818  1957-04-13  1957    Unprovoked         AUSTRALIA
# 6824  1955-11-16  1955    Unprovoked  PAPUA NEW GUINEA
# 6844  1936-02-04  1936    Unprovoked         AUSTRALIA
#
#                               area  \
# 6                           Hawaii
# 10                         Florida
# 13                    North Island
# 19                    South Island
# 22                      California
# ...                            ...
# 6816  Between Hawaii & Wake Island
# 6817               New South Wales
# 6818                 Torres Strait
# 6824              Central Province
# 6844               New South Wales
#
#                                                location  \
# 6                               Marine Corps Base, Oahu
# 10                                         Ormond Beach
# 13                                        Pauanui Beach
# 19                                          Oreti Beach
# 22                          Oceanside, San Diego County
# ...                                                 ...
# 6816                    600 miles northwest of Honolulu
# 6817                                    Brunswick Heads
# 6818                Thursday Island Harbour, Queensland
# 6824  Kalautu Village, Baibara at the mouth of Oibad...
# 6844                                South Steyne, Manly
#
#                                                activity  \
# 6                                               Surfing
# 10                                             Swimming
# 13                                              Surfing
# 19                                      Boogie boarding
# 22                                             Paddling
# ...                                                 ...
# 6816  U.S. Airforce C124 enroute from Hickham Air Ba...
# 6817                                       Body surfing
# 6818       Swimming between  anchored  pearling luggers
# 6824                                           Swimming
# 6844                                           Swimming
#
#                                name sex  age  \
# 6                 Parker Blanchette   M   14
# 10                    Jordan Hooper   M   17
# 13                     Nick Minogue   M   60
# 19                           female   F   17
# 22                      Julie Wolfe   F   57
# ...                             ...  ..  ...
# 6816  Captain Jonathan Brown, pilot   M   31
# 6817                Brian Henderson   M   14
# 6818                 Tuisafua Nomoa   M   22
# 6824                       Niu Bodu   M    8
# 6844                    David Paton   M   14
#
#                                                  injury fatal_y_n     time  \
# 6                          Lacerations to shin and calf         N    16h00
# 10                                       Minor injuries         N    16h00
# 13                       Minor injury, surfboard bitten         N    11h30
# 19                                        Gash to thigh         N  Evening
# 22    No injury to occupant, outrigger canoe and pad...         N    18h00
# ...                                                 ...       ...      ...
# 6816                               Left shoulder bitten         N    10h25
# 6817      Laceration to left ankle, heel and little toe         N    16h30
# 6818              Left arm bitten, surgically amputated         N    14h00
# 6824                                 Right thigh bitten         N    18h00
# 6844  FATAL, taken by shark, body not recovered. Twe...         Y    15h00
#
#                                                 species  \
# 6                                          5.5 ft shark
# 10                             Blacktip shark, 6' to 7'
# 13                                          White shark
# 19    Reported as shark bite but injury caused by st...
# 22                                          White shark
# ...                                                 ...
# 6816               Sharks averaged 1.8 m [6'] in length
# 6817                                           6' shark
# 6818  Shark seen feeding on turtle scraps thrown ove...
# 6824                                    Wobbegong shark
# 6844                                        White shark
#
#                                               Species_1  Species_2 Species_3  \
# 6                                          5.5 ft shark       None      None
# 10                                       Blacktip shark   6' to 7'      None
# 13                                          White shark       None      None
# 19    Reported as shark bite but injury caused by st...       None      None
# 22                                          White shark       None      None
# ...                                                 ...        ...       ...
# 6816               Sharks averaged 1.8 m [6'] in length       None      None
# 6817                                           6' shark       None      None
# 6818  Shark seen feeding on turtle scraps thrown ove...       None      None
# 6824                                    Wobbegong shark       None      None
# 6844                                        White shark       None      None
#
#      Species_4
# 6         None
# 10        None
# 13        None
# 19        None
# 22        None
# ...        ...
# 6816      None
# 6817      None
# 6818      None
# 6824      None
# 6844      None
#
# [1622 rows x 18 columns]

# %%
# remove unnecessary column
del fixed_data_df['species']

# %%
fixed_data_df
# Out:
#             date  year          type           country  \
# 6     2021-05-03  2021    Unprovoked               USA
# 10    2020-10-31  2020    Unprovoked               USA
# 13    2020-02-22  2020    Unprovoked       NEW ZEALAND
# 19    2019-01-29  2019       Invalid       NEW ZEALAND
# 22    2018-06-25  2018    Watercraft               USA
# ...          ...   ...           ...               ...
# 6816  1958-07-04  1958  Sea Disaster     PACIFIC OCEAN
# 6817  1958-01-19  1958    Unprovoked         AUSTRALIA
# 6818  1957-04-13  1957    Unprovoked         AUSTRALIA
# 6824  1955-11-16  1955    Unprovoked  PAPUA NEW GUINEA
# 6844  1936-02-04  1936    Unprovoked         AUSTRALIA
#
#                               area  \
# 6                           Hawaii
# 10                         Florida
# 13                    North Island
# 19                    South Island
# 22                      California
# ...                            ...
# 6816  Between Hawaii & Wake Island
# 6817               New South Wales
# 6818                 Torres Strait
# 6824              Central Province
# 6844               New South Wales
#
#                                                location  \
# 6                               Marine Corps Base, Oahu
# 10                                         Ormond Beach
# 13                                        Pauanui Beach
# 19                                          Oreti Beach
# 22                          Oceanside, San Diego County
# ...                                                 ...
# 6816                    600 miles northwest of Honolulu
# 6817                                    Brunswick Heads
# 6818                Thursday Island Harbour, Queensland
# 6824  Kalautu Village, Baibara at the mouth of Oibad...
# 6844                                South Steyne, Manly
#
#                                                activity  \
# 6                                               Surfing
# 10                                             Swimming
# 13                                              Surfing
# 19                                      Boogie boarding
# 22                                             Paddling
# ...                                                 ...
# 6816  U.S. Airforce C124 enroute from Hickham Air Ba...
# 6817                                       Body surfing
# 6818       Swimming between  anchored  pearling luggers
# 6824                                           Swimming
# 6844                                           Swimming
#
#                                name sex  age  \
# 6                 Parker Blanchette   M   14
# 10                    Jordan Hooper   M   17
# 13                     Nick Minogue   M   60
# 19                           female   F   17
# 22                      Julie Wolfe   F   57
# ...                             ...  ..  ...
# 6816  Captain Jonathan Brown, pilot   M   31
# 6817                Brian Henderson   M   14
# 6818                 Tuisafua Nomoa   M   22
# 6824                       Niu Bodu   M    8
# 6844                    David Paton   M   14
#
#                                                  injury fatal_y_n     time  \
# 6                          Lacerations to shin and calf         N    16h00
# 10                                       Minor injuries         N    16h00
# 13                       Minor injury, surfboard bitten         N    11h30
# 19                                        Gash to thigh         N  Evening
# 22    No injury to occupant, outrigger canoe and pad...         N    18h00
# ...                                                 ...       ...      ...
# 6816                               Left shoulder bitten         N    10h25
# 6817      Laceration to left ankle, heel and little toe         N    16h30
# 6818              Left arm bitten, surgically amputated         N    14h00
# 6824                                 Right thigh bitten         N    18h00
# 6844  FATAL, taken by shark, body not recovered. Twe...         Y    15h00
#
#                                               Species_1  Species_2 Species_3  \
# 6                                          5.5 ft shark       None      None
# 10                                       Blacktip shark   6' to 7'      None
# 13                                          White shark       None      None
# 19    Reported as shark bite but injury caused by st...       None      None
# 22                                          White shark       None      None
# ...                                                 ...        ...       ...
# 6816               Sharks averaged 1.8 m [6'] in length       None      None
# 6817                                           6' shark       None      None
# 6818  Shark seen feeding on turtle scraps thrown ove...       None      None
# 6824                                    Wobbegong shark       None      None
# 6844                                        White shark       None      None
#
#      Species_4
# 6         None
# 10        None
# 13        None
# 19        None
# 22        None
# ...        ...
# 6816      None
# 6817      None
# 6818      None
# 6824      None
# 6844      None
#
# [1622 rows x 17 columns]

# %%
# remove unnecesary column
del fixed_data_df['time']

# %%
fixed_data_df
# Out:
#             date  year          type           country  \
# 6     2021-05-03  2021    Unprovoked               USA
# 10    2020-10-31  2020    Unprovoked               USA
# 13    2020-02-22  2020    Unprovoked       NEW ZEALAND
# 19    2019-01-29  2019       Invalid       NEW ZEALAND
# 22    2018-06-25  2018    Watercraft               USA
# ...          ...   ...           ...               ...
# 6816  1958-07-04  1958  Sea Disaster     PACIFIC OCEAN
# 6817  1958-01-19  1958    Unprovoked         AUSTRALIA
# 6818  1957-04-13  1957    Unprovoked         AUSTRALIA
# 6824  1955-11-16  1955    Unprovoked  PAPUA NEW GUINEA
# 6844  1936-02-04  1936    Unprovoked         AUSTRALIA
#
#                               area  \
# 6                           Hawaii
# 10                         Florida
# 13                    North Island
# 19                    South Island
# 22                      California
# ...                            ...
# 6816  Between Hawaii & Wake Island
# 6817               New South Wales
# 6818                 Torres Strait
# 6824              Central Province
# 6844               New South Wales
#
#                                                location  \
# 6                               Marine Corps Base, Oahu
# 10                                         Ormond Beach
# 13                                        Pauanui Beach
# 19                                          Oreti Beach
# 22                          Oceanside, San Diego County
# ...                                                 ...
# 6816                    600 miles northwest of Honolulu
# 6817                                    Brunswick Heads
# 6818                Thursday Island Harbour, Queensland
# 6824  Kalautu Village, Baibara at the mouth of Oibad...
# 6844                                South Steyne, Manly
#
#                                                activity  \
# 6                                               Surfing
# 10                                             Swimming
# 13                                              Surfing
# 19                                      Boogie boarding
# 22                                             Paddling
# ...                                                 ...
# 6816  U.S. Airforce C124 enroute from Hickham Air Ba...
# 6817                                       Body surfing
# 6818       Swimming between  anchored  pearling luggers
# 6824                                           Swimming
# 6844                                           Swimming
#
#                                name sex  age  \
# 6                 Parker Blanchette   M   14
# 10                    Jordan Hooper   M   17
# 13                     Nick Minogue   M   60
# 19                           female   F   17
# 22                      Julie Wolfe   F   57
# ...                             ...  ..  ...
# 6816  Captain Jonathan Brown, pilot   M   31
# 6817                Brian Henderson   M   14
# 6818                 Tuisafua Nomoa   M   22
# 6824                       Niu Bodu   M    8
# 6844                    David Paton   M   14
#
#                                                  injury fatal_y_n  \
# 6                          Lacerations to shin and calf         N
# 10                                       Minor injuries         N
# 13                       Minor injury, surfboard bitten         N
# 19                                        Gash to thigh         N
# 22    No injury to occupant, outrigger canoe and pad...         N
# ...                                                 ...       ...
# 6816                               Left shoulder bitten         N
# 6817      Laceration to left ankle, heel and little toe         N
# 6818              Left arm bitten, surgically amputated         N
# 6824                                 Right thigh bitten         N
# 6844  FATAL, taken by shark, body not recovered. Twe...         Y
#
#                                               Species_1  Species_2 Species_3  \
# 6                                          5.5 ft shark       None      None
# 10                                       Blacktip shark   6' to 7'      None
# 13                                          White shark       None      None
# 19    Reported as shark bite but injury caused by st...       None      None
# 22                                          White shark       None      None
# ...                                                 ...        ...       ...
# 6816               Sharks averaged 1.8 m [6'] in length       None      None
# 6817                                           6' shark       None      None
# 6818  Shark seen feeding on turtle scraps thrown ove...       None      None
# 6824                                    Wobbegong shark       None      None
# 6844                                        White shark       None      None
#
#      Species_4
# 6         None
# 10        None
# 13        None
# 19        None
# 22        None
# ...        ...
# 6816      None
# 6817      None
# 6818      None
# 6824      None
# 6844      None
#
# [1622 rows x 16 columns]

# %%
# check species_1 column to see what unique values exist
species= fixed_data_df['Species_1'].unique()
species
# Out:
# array(['5.5 ft shark', 'Blacktip shark', 'White shark',
#        'Reported as shark bite but injury caused by stingray',
#        'Questionable', 'Wobbegong shark', '3 m shark',
#        'Shark involvement not confirmed', 'Tiger shark', 'Bull shark',
#        "8' to 10' shark", "2' to 3' shark", "3.5' to 4' shark",
#        'Nurse shark', 'Tawny nurse shark', "6' shark",
#        "8' white shark or 7-gill shark",
#        'Reported by media as shark attack', 'A bull shark', '2 m shark',
#        "3' shark", "6' to 8' shark", "6 m [20'] white shark",
#        "A 2' shark was seen in the area by witnesses", 'juvenile shark',
#        'Tiger shark?', "1.8 m [6'] shark",
#        "4 m to 5 m [13' to 16.5']  white shark",
#        "5 m to 6 m [16.5' to 20'] white shark", 'Lemon shark',
#        '3.5 m white shark', "3 m to 5 m [10' to 16.5'] white shark",
#        'Raggedtooth shark', "4 m to 5 m [13' to 16.5'] white shark",
#        'Questionable incident', "14' shark",
#        "3 m [10'] shark seen in vicinity", 'Possibly C. leucas',
#        "8' shark", "5' to 6' shark", 'Broadnose seven gill shark?',
#        "10'-12' tiger shark", "12' shark", 'Salmon shark', 'Blue shark',
#        "4' to 5' shark", '3 m to 4 m white shark', 'Zambesi shark',
#        'Thought to involve a cookiecutter shark', "+3' shark",
#        'Shark involvement prior to death was not confirmed',
#        "3' to 4' shark", 'juvenile white shark', "[4' to 5']",
#        'Mako shark', "1.2 m [4'] bull shark", 'Unidentified species',
#        "1.2 m [4'] shark",
#        "2.7 m [9']  bull shark or Caribbean reef shark",
#        "5' spinner shark", "5.5 m to 6 m [18' to 20'] white shark",
#        '4.2 m white shark', "2.4 m [8'] shark",
#        "2.3 m [7.5'] white shark", "1.2 m [4'] dusky shark",
#        "3.5 m [11.5'] white shark", "3 m [10'] shark",
#        "Believed to involve a 2.8 m [9'3] white shark",
#        'Juvenile dusky shark', 'small blacktip shark', 'Grey nurse shark',
#        'Local authorities speculated that the water was too cold for sharks',
#        'Hammerhead shark', 'Invalid', '60 cm  shark', "1.2 m [4']",
#        '>1.6 m shark', 'Blacktip or spinner shark', 'Sandtiger shark',
#        'Species unidentified',
#        "0.9 m to 1.2 m [3' to 4'] shark; Tooth fragment recovered from hand",
#        "3' blacktip shark", 'Bull shark?', 'small shark',
#        "5.5 m [18'] white shark", "4 m [13'] white shark",
#        "3 m [10'] bull shark", '4.3 m shark', "1.5 m [5'] dusky shark",
#        '4.5 m to 5 m white shark',
#        'Questionable incident; reported as shark attack but thought to involve a pinniped instead',
#        "7 m [23'] white shark", 'Spinner or blacktip sharks',
#        "1.8 m [6']", ">1.2 m [4'] tiger shark",
#        "Hand found in gut of 2.9 m to 3.3 m [9'7 to 10'11] Galapagos shark",
#        'Horn shar', 'A hammerhead shark', "2.4 m [8']  shark", "4' shark",
#        '1.5 m', 'Identified as C. gangeticus by Dr. J. Fayrer',
#        'Grey reef shark',
#        'Reported as shark attacks but injuries caused by toadfish',
#        'Possibly a juvenile blacktip shark', '1.5 m shark',
#        "4' tp 5' shark", 'Bronze whaler shark',
#        "2 m [6.75'] sevengill  shark",
#        "1.2 m [4'] blacktip or sandbar shark",
#        'Possibly a blacktip shark',
#        'Thought to involve a small sand shark',
#        "1.2 m [4'] spinner shark", "2.5 m [8.25'] white shark",
#        "2.7 m [9'] white shark", "2 m [6.75'] white shark",
#        'Zambezi shark (tooth fragments recovered)',
#        "2.4 m [8'] white shark", "1.8 m to 2.4 m [6' to 8'] shark",
#        "1.5 m [5'] shark",
#        '2 days later a 600-lb shark was caught 100 yards from the site',
#        'Bronze whaler', "9' shark", 'Shovelnose shark which is a ray',
#        "2' shark", 'Cookiecutter shark', 'Broadnose sevengill shark',
#        "3' to 5' shark", '3- to 4-foot shark', "7' shark",
#        'Spinner shark', "Possibly a 5' to 6' bull shark", '1',
#        "0.9 m  to 1.2 m [3' to 4'] shark", 'Shortfin mako shark',
#        '3 bull sharks', 'A small shark', 'Possibly a tiger shark',
#        '4 m shark', "1.2 m to 1.5 m [4' to 5'] shark",
#        'Thought to involve a tiger shark',
#        "2.5 m to 3 m [8.25' to 10']  white shark",
#        "3 m [10'] white shark", 'Possibly a small hammerhead shark',
#        'Hammerhead shark?+O2356', 'C. maculpinnis or C. limbatus',
#        "2.8 m [9'3] white shark", 'A pack of 6 sharks',
#        "1.7 m [5.5'] shark",
#        "Said to involve 2 sharks: 5.2 m & 6 m [17' & 20']",
#        "4.6 m [15'] shark",
#        'Shark involvement prior to death unconfirmed',
#        "Thought to involve a 2.6 m [8.5'] white shark", '8 shark',
#        'Oceanic whitetip shark', "Thought to involve a 3' to 4' shark",
#        "15' shark", '2.6 m shark', "9.5' shark?", 'No shark involvement',
#        "12' to 18' shark", "18' white shark",
#        "3 m to 4.5 m [10' to 15'] white shark",
#        "3 m to 3.7 m [10' to 12'] shark", "0.9 m [3'] shark",
#        'Unidentified', "1.2 m to 1.8 m [4' to 6'] shark",
#        "5.5 m to 6 m [18' to 20']  white shark",
#        "5 m [16.5'] white shark",
#        "Said to involve a 6 m to 7 m [20' to 23'] white shark",
#        "0.9 m to 1.2 m [3' to 4'] shark", "12' to 14' shark",
#        "1.5 m to 1.8 m [5' to 6'] sandbar shark", 'Grey nurse shark?',
#        "5' shark", 'possibly a bull shark', 'Spurdog',
#        "2.4 m to 3.7 m [8' to 12'] shark",
#        "4.5 m to 5.5 m [15' to 18'] white shark", 'a small shark',
#        '2.5 m shark', 'Possibly a white shark',
#        "1.2 m to 1.5 m [4' to 5']   shark", 'sand shark',
#        "2.7 m [9'] shark", ">1.8 m [6'] shark", ">6 m [20'] white shark",
#        "1.8 m [6'] blacktip shark or Caribbean reef shark",
#        "3.7 m [12'] shark", "1.8 to 2.4 m [6' to 8'] shark",
#        'White shark (tooth fragment recovered)', "1.8 m [6']  shark",
#        "gummy shark (Rhizoprionodon or Loxodon) 1.2 m [4']",
#        "Two 2.1 m [7'] sharks", "1.8 to 2.1 m [6' to 7'] shark",
#        '3.6 m  white shark  (or bronze whaler)',
#        'Thought to involve a mako or grey nurse shark', 'reef shark',
#        '2 small bull sharks', '24 to 30 shark', 'Whitetip reef shark',
#        "On 8/13/2005 anglers from New Zealand caught a 2.8 m [9'3]",
#        "1.9 m [6.5'] bull shark",
#        "1.2 m to 1.5 m [4' to 5'] hammerhead shark", '6 m  white shark',
#        "4' to 8' shark", '300- to 400-lb Zambesi shark',
#        'Possibly a bronze whaler shark', 'Sickelfin lemon shark',
#        "Hammerhead shark. 6' to 7'", "10' shark", "4' to 6' shark",
#        'Thought to involve a Bronze whale shark',
#        'Not a shark attack; it was a hoax', 'White shark?', '1.8 m shark',
#        "Mr. Burgess of ISAF announced the injury was the bite of a 1.8 m [6']",
#        '2 sharks', '“small brown shark”',
#        "3.7 m to 4.3 m [12' to 14'] white shark", "3'  shark",
#        "6 m [20'] shark", '1.3 to 1.6 m shark',
#        'Though to involve a white shark', 'Small shark', '150-lb shark',
#        'Mako shark (tooth fragments recovered)',
#        'Thought to involve a blacktip shark',
#        'Tooth fragments of “whaler” shark were recovered',
#        "4.3 m [14'] shark",
#        "Said to involve 6 to 7 m [20' to 23'] white shark",
#        'Epaulette shark', "6.5' shark", 'Bull shark pup',
#        "Said to involve an 8' shark but more likely damage caused by debris",
#        '2 m to  3 m shark', 'Possibly a small blacktip shark',
#        'Angel shark', "14' white shark", "4 m [13'] shark",
#        "0.9 m to 1.5 m [3' to 5'] shark",
#        "2.4 m to 3 m [8' to 10'] grey colored shark", 'bull shark',
#        'Caribbean reef shark', "1.5 to 1.8 m [5' to 6'] shark",
#        "1.3 m [4'3] shark", "2.4 m to 3 m [8' to 10'] white shark",
#        'Dusky shark',
#        'Dooley believed his Injury was caused by stingray (Dasyatidae family)',
#        ">3 m [10'] shark", 'Blacktip or Spinner shark',
#        "10' to 12' shark", 'White shark or bronze whaler',
#        '2 to 2.5 m shark', "2.1 m  [7'] bull shark",
#        'A large white shark was filmed by divers on a local wreck 2 days prior to the incident.',
#        'Unidentified shark', 'Sand shark?', '7-gill shark',
#        "3.7 to 4.5 m [12' to 15'] shark seen in vicinity",
#        'Reported as  a shark bite but toothmarks appear to be those of a dolphin',
#        'Sevengill shark', '1.3m shark', 'Shark involvement questionable',
#        '3+ m shark', 'White shark or oceanic whitetip shark',
#        'Port Jackson shark', '5 m white shark',
#        "8' bull shark or Caribbean reef shark", "5' to 7' shark",
#        "9'2 white shark",
#        '15 cm to 20 cm [6 to 8] bite diameter just below left knee',
#        'Possibly a juvenile blacktip or spinner shark',
#        '5 m to 6 m white shark', ">2.4 m [8'] white shark",
#        "1.2 m [4'] blacktip shark", "6' to 8' bull shark",
#        'White shark tooth fragment recovered from ankle & identified by Dr. W. I. Follett',
#        '1m shark', 'dogfish shark', "2 white shark: 13' & 98",
#        'Possibly a blacktip reef shark', 'Allegedly a 4 m tiger shark',
#        'Shark involvement prior to death not confirmed',
#        'White shark x 2', '2m shark', 'Thresher shark',
#        'blacktip or spinner shark', "1.5' to 2' shark",
#        "1.8 m [6'] bull shark", 'Shark involvement doubtful',
#        'Possibly a bull shark or tiger shark',
#        'Bull shark or lemon shark', "4' spinner shark",
#        '1 m grey-colored shark', "2 m to 2.5 m [6.75'  to 8.25'] shark",
#        "1.5 m to 1.8m [5' to 6'] shark", '1 m shark',
#        'Reported to involve a White shark', 'Galapagos shark',
#        'Thought to involve a bull shark', '20 to 30kg shark',
#        '18 to 24 shark', "Possibly a 6' bull shark",
#        'Questionable incident - shark bite may have precipitated drowning',
#        'Thought to involve a 5.5 m white shark named Kong',
#        '1.5 m copper shark',
#        "1.8 m to 2.1 m [6' to 7'] spinner or blacktip shark",
#        "2 m to 2.5 m [6.75'  to 8.25'] sixgill or sevengill shark",
#        "4.5 m to 5.5 m [14.7' to 18'] white shark",
#        "1.2 m to 1.5 m [4' to 5'] bull", 'Sevengill  shark',
#        "Tiger shark. 14'3", 'Said to involve a bull shark',
#        'Wobbegong shark?', "Possibly a 5' to 6' sandtiger shark",
#        'Shark involvement not confirmed; thought to be a barracuda bite',
#        'A 10-year-old 94-pound pregnant blacktip reef shark',
#        "12' to 14' white shark",
#        "Thought to involve a >2 m [6.75'] bull shark", 'A “small” shark',
#        "1' to 2' hammerhead or bonnethed shark", 'Zambesi shark?',
#        'Possibly a sand shark', "1.8 m to 2.1 m [6' to 7'] shark",
#        '>2 m shark', "1.8 m [6'] blacktip shark",
#        "2.1 m [7'] lemon shark or bull shark",
#        'Thought to involve a white shark',
#        "3 m to 4.3 m [10' to 14'] shark", '3m shark',
#        '5 to 8-ff tiger shark', 'Blacktip whaler', 'Juvenile shark',
#        'Reef shark', "4.5 to 5' shark",
#        "Possibly a 1' to 3' blacktip or spinner shark",
#        "3.7 m to 4.6 m [12' to 15'] shark seen in the vicinity",
#        'a young shark', "3 m to 4 m [10' to 13'] white shark",
#        "2 m [6.75'] shark", '5.7 m white shark',
#        'A long thin brown-colored shark', '36  shark', "2.1 m [7'] shark",
#        'small blacktip shark?', "1.2 m [4'] grey-colored shark",
#        "1.8 m [6'] reef shark - or a 2.1 m to 2.4 m [7' to 8'] grey-colored shark",
#        "2.7 m [9'] bull or lemon shark", "4.5 m [14'9] white shark",
#        '>1 m shark', "1.8 m [6'] white shark", '200-lb shark',
#        'White shark (identified by Dr. Hugh Smith)',
#        'Juvenile white shark', "1' to 2' shark",
#        'possibly a bronze whaler shark', "2.5 m [8.25'] bull shark",
#        "3.7 m to 4.3 m [12' to 14'] shark",
#        'Possibly  a blacktip or spinner shark',
#        "3 to 3.5 m [10' to 11.5'] bull shark",
#        "1.8 m to 2.4 m [6' to 8'] hammerhead shark", "4.5' shark",
#        "5' blue shark", "2.1 m [7']",
#        "2.4 m [8'] tiger shark caught 40 hours later with shorts of the boy in its gut",
#        "2.6 m [8.5'] shark landed 2 hours later",
#        "4.3 m [14'] shark seen in area previous week",
#        'Blacktip reef shark', 'Porbeagle shark',
#        "5' to 6' spinner or bull shark", '1 m  shark',
#        "0.9 m  [3'] shark", "60 cm to 90 cm [2' to 3'] shark",
#        'Tiger shark caught 6 days later with diver’s remains in its gut',
#        "Possibly a 1.5 m [5'] blacktip shark",
#        "1.5 m to 2 m [5' to 6.75'] shark", 'Copper shark',
#        'Possibly a broadnose 7-gill shark', 'According to Benjamin',
#        'White xhark', "7' to 8' shark", 'Whaler or bull shark',
#        '3.5 m shark', 'Reported to involve a bull shark',
#        '1.5 to 2 m shark', '2 m to 3 m shark', "14' to 16' white shark",
#        "1.5 m [5'] whaler shark", 'Bronze whaler or tiger shark',
#        ">2.5 m [8.25'] white shark", "7' to 8' bull shark",
#        '500-lb shark', 'Unknown', "4 m [13'] shark seen in vicinity",
#        'White Shark', 'Oceanic whitetip sharks were in the vicinity',
#        'Caribbean reef sharks', "4.9 m to 5.5 m [16' to 18'] white shark",
#        "3.5' to 4.5' shark", "1.2 m [4'] shark (spinner shark?)",
#        "5 m to 5.5 m [16.5' to 18'] white shark",
#        "6' to 7' blacktip shark",
#        'Shark involvement suspected but not confirmed',
#        "3.5' hammerhead shark",
#        'Said to involve a tiger shark or a hammerhead shark',
#        "Possibly a  1.8 m [6'] Zambezi shark",
#        '1.8 to 2 m C. albimarginatus', "1.8 m to 2 m [6' to 6'9] shark",
#        "3.7 m [12'] shark & may have been another shark nearby",
#        'a small reef shark', 'Possibly a spinner shark', '2 to 3 m shark',
#        'Possibly a sandbar shark or small blacktip shark',
#        "1.8 m to 2.1 m [6' to 7']\xa0 Caribbean Reef Shark",
#        "2' to 3.5' shark",
#        "Possibly a 1.5 m [5'] blacktip or spinner shark",
#        "2.1 to 2.4 m [7' to 8'] shark",
#        'Small dusky shark or blackfin shark',
#        "Remains recovered from 5.5 m [18'] white shark",
#        "2 m [6'9] Zambesi shark",
#        "1.5 m to 1.8 m [5' to 6'] Zambesi shark", "5.5 m [18'] shark",
#        "3.5 m [11.5'] shark",
#        "Moreno’s leg  & part of his swim suit found in 9' shark caught two hours after the attack. Identified as carcharhinid shark by L. Schultz & C. Limbaugh on photograph",
#        "Thought to involve a 4' sandtiger shark", '1+ m shark',
#        'Reef shark x 2', 'Hammerhead shark.', "14' to 18'shark",
#        '80 kg shark', "Possibly a 10' bull shark",
#        "Thought to involve a 2 m [6.75'] grey nurse shark",
#        ">3.4 m [11'] white shark",
#        "Next morning a 3 m [10'] shark was caught that had Andrews' leg in its gut",
#        '136-kg [300-lb] shark', "Said to be 6.4 m [21'] shark",
#        "4.3 m [14'] shark seen in vicinity",
#        "2.8 m [9'3] whaler shark captured 3 days later with his remains in its gut",
#        'Blacktip shark?', 'Bronze whaler 1.5m', '3.5 to 4 m shark',
#        'Sandbar shark', 'Nurse shark?', 'Lesser spotted dogfish',
#        '2.5 to 3 m shark', "Thought to involve a 2.7 m [9']",
#        '4.5 m white shark', "1.8 m to 2.1 m [6' to 7'] hammerhead shark",
#        '4 m white shark', "5 m  [16.5'] white shark",
#        "3.5 m [11.5']  white shark", "1.8 m [6'] Zambezi shark",
#        'Juvenile dusky or blacktip shark',
#        'White shark according to tooth pattern and witnesses',
#        "1.5 m to 1.8 m [5' to 6'] shark", '43 shark',
#        'Thought to involve a Zambesi shark', '4m shark', "5' to 8' shark",
#        'Shark involvement highly doubtful', 'Small bull shark',
#        '3 m to 4 m shark', "3' to 3.5' shark", '4.5 m & 5 m white shark',
#        'Bull or tiger shark',
#        "60 cm to 90 cm [2' to 3'] blacktip or spinner shark", "3 m [10']",
#        '1.6 m shark', "4m [13'] shark", "3.3 m [10'9] shark",
#        "White shark 4.9 m [16']", "1.8 m to 2.7 m [6' to 9'] shark",
#        'Invalid incident', "6' to 7' shark", 'white shark',
#        'Bronze whaler shark?', "1.2 m [4'] hammerhead shark",
#        'whitetip shark', '1m to 1.2 m shark', '7-gill shark?',
#        'Possibly a bull shark', '4 to 5m white shark', "2.5' shark",
#        'Thought to involve a 2.5 m bull or tiger shark', 'Sand shark',
#        '1.5 m to 2 m shark', "Mako shark (aka bonito shark) 1.2 m [4']",
#        "2.7 m [9'] blue shark", 'Shark involvement probable',
#        "[4.5' to 5'] shark", "106 cm [3.5']  shark",
#        'C. leucas tooth fragment recovered from kayak',
#        'Shark involvement not confirmed; officials considered barracua',
#        "Sharks averaged 1.8 m [6'] in length",
#        'Shark seen feeding on turtle scraps thrown overboard prior to incident.'],
#       dtype=object)

# %%
# look at value counts of species 1 to determine which values need to be cleaned/removed
fixed_data_df['Species_1'].value_counts().head(25)
# Out:
# Species_1
# White shark                                           261
# Tiger shark                                           136
# Bull shark                                             73
# 4' shark                                               36
# Bronze whaler shark                                    29
# Blacktip shark                                         28
# Raggedtooth shark                                      25
# Shark involvement not confirmed                        25
# 4' to 5' shark                                         21
# 1.8 m [6'] shark                                       21
# 6' shark                                               19
# Nurse shark                                            18
# Invalid                                                16
# 3' shark                                               16
# Mako shark                                             15
# 3' to 4' shark                                         15
# Grey nurse shark                                       15
# 1.5 m [5'] shark                                       14
# 5' shark                                               14
# Wobbegong shark                                        14
# 1.2 m [4'] shark                                       14
# 1.2 m to 1.5 m [4' to 5'] shark                        13
# Shark involvement prior to death was not confirmed     11
# 6 m [20'] white shark                                  10
# Zambesi shark                                          10
# Name: count, dtype: int64

# %%
# clean species_1
fixed_data_df['Species_1'] = fixed_data_df['Species_1'].replace({"4' shark": 'Unknown',"4' to 5' shark": 'Unknown',"1.8 m [6'] shark":'Unknown',
"6' shark":'Unknown',"Invalid":'Unknown',"3' shark": 'Unknown'})

# %%
# create a list of sharks
top_sharks = fixed_data_df['Species_1'].value_counts().head(10).keys().to_list()

# %%
# make an empty dataframe and create df list
top_shark_df = fixed_data_df.head(0).copy()
dfs = []

# %%
# create list of top shark dataframes
for shark in top_sharks:
    dfs.append(fixed_data_df.loc[fixed_data_df['Species_1'] == shark])

# %%
# combine dataframes
for df in dfs:
   top_shark_df= pd.concat([top_shark_df,df])

# %%
# view top 20 shark species
top_shark_df['Species_1'].value_counts().head(20)
# Out:
# Species_1
# White shark                        261
# Tiger shark                        136
# Unknown                            131
# Bull shark                          73
# Bronze whaler shark                 29
# Blacktip shark                      28
# Raggedtooth shark                   25
# Shark involvement not confirmed     25
# Nurse shark                         18
# Grey nurse shark                    15
# Name: count, dtype: int64

# %%
# filter to white sharks only
fixed_data_df['Species_1'].loc[fixed_data_df['Species_1'] =='White shark' ]
# Out:
# 13      White shark
# 22      White shark
# 24      White shark
# 37      White shark
# 45      White shark
#            ...
# 6679    White shark
# 6725    White shark
# 6797    White shark
# 6808    White shark
# 6844    White shark
# Name: Species_1, Length: 261, dtype: object

# %%
# create list of top sharks
fixed_data_df['Species_1'].value_counts().head().keys().to_list()
# Out:
# ['White shark', 'Tiger shark', 'Unknown', 'Bull shark', 'Bronze whaler shark']

# %%
# reprint dataframe
fixed_data_df
# Out:
#             date  year          type           country  \
# 6     2021-05-03  2021    Unprovoked               USA
# 10    2020-10-31  2020    Unprovoked               USA
# 13    2020-02-22  2020    Unprovoked       NEW ZEALAND
# 19    2019-01-29  2019       Invalid       NEW ZEALAND
# 22    2018-06-25  2018    Watercraft               USA
# ...          ...   ...           ...               ...
# 6816  1958-07-04  1958  Sea Disaster     PACIFIC OCEAN
# 6817  1958-01-19  1958    Unprovoked         AUSTRALIA
# 6818  1957-04-13  1957    Unprovoked         AUSTRALIA
# 6824  1955-11-16  1955    Unprovoked  PAPUA NEW GUINEA
# 6844  1936-02-04  1936    Unprovoked         AUSTRALIA
#
#                               area  \
# 6                           Hawaii
# 10                         Florida
# 13                    North Island
# 19                    South Island
# 22                      California
# ...                            ...
# 6816  Between Hawaii & Wake Island
# 6817               New South Wales
# 6818                 Torres Strait
# 6824              Central Province
# 6844               New South Wales
#
#                                                location  \
# 6                               Marine Corps Base, Oahu
# 10                                         Ormond Beach
# 13                                        Pauanui Beach
# 19                                          Oreti Beach
# 22                          Oceanside, San Diego County
# ...                                                 ...
# 6816                    600 miles northwest of Honolulu
# 6817                                    Brunswick Heads
# 6818                Thursday Island Harbour, Queensland
# 6824  Kalautu Village, Baibara at the mouth of Oibad...
# 6844                                South Steyne, Manly
#
#                                                activity  \
# 6                                               Surfing
# 10                                             Swimming
# 13                                              Surfing
# 19                                      Boogie boarding
# 22                                             Paddling
# ...                                                 ...
# 6816  U.S. Airforce C124 enroute from Hickham Air Ba...
# 6817                                       Body surfing
# 6818       Swimming between  anchored  pearling luggers
# 6824                                           Swimming
# 6844                                           Swimming
#
#                                name sex  age  \
# 6                 Parker Blanchette   M   14
# 10                    Jordan Hooper   M   17
# 13                     Nick Minogue   M   60
# 19                           female   F   17
# 22                      Julie Wolfe   F   57
# ...                             ...  ..  ...
# 6816  Captain Jonathan Brown, pilot   M   31
# 6817                Brian Henderson   M   14
# 6818                 Tuisafua Nomoa   M   22
# 6824                       Niu Bodu   M    8
# 6844                    David Paton   M   14
#
#                                                  injury fatal_y_n  \
# 6                          Lacerations to shin and calf         N
# 10                                       Minor injuries         N
# 13                       Minor injury, surfboard bitten         N
# 19                                        Gash to thigh         N
# 22    No injury to occupant, outrigger canoe and pad...         N
# ...                                                 ...       ...
# 6816                               Left shoulder bitten         N
# 6817      Laceration to left ankle, heel and little toe         N
# 6818              Left arm bitten, surgically amputated         N
# 6824                                 Right thigh bitten         N
# 6844  FATAL, taken by shark, body not recovered. Twe...         Y
#
#                                               Species_1  Species_2 Species_3  \
# 6                                          5.5 ft shark       None      None
# 10                                       Blacktip shark   6' to 7'      None
# 13                                          White shark       None      None
# 19    Reported as shark bite but injury caused by st...       None      None
# 22                                          White shark       None      None
# ...                                                 ...        ...       ...
# 6816               Sharks averaged 1.8 m [6'] in length       None      None
# 6817                                            Unknown       None      None
# 6818  Shark seen feeding on turtle scraps thrown ove...       None      None
# 6824                                    Wobbegong shark       None      None
# 6844                                        White shark       None      None
#
#      Species_4
# 6         None
# 10        None
# 13        None
# 19        None
# 22        None
# ...        ...
# 6816      None
# 6817      None
# 6818      None
# 6824      None
# 6844      None
#
# [1622 rows x 16 columns]

# %%
# drop row with incorrect date and reprint dataframe
clean_data_df = fixed_data_df.drop(fixed_data_df.index[808])
clean_data_df
# Out:
#             date  year          type           country  \
# 6     2021-05-03  2021    Unprovoked               USA
# 10    2020-10-31  2020    Unprovoked               USA
# 13    2020-02-22  2020    Unprovoked       NEW ZEALAND
# 19    2019-01-29  2019       Invalid       NEW ZEALAND
# 22    2018-06-25  2018    Watercraft               USA
# ...          ...   ...           ...               ...
# 6816  1958-07-04  1958  Sea Disaster     PACIFIC OCEAN
# 6817  1958-01-19  1958    Unprovoked         AUSTRALIA
# 6818  1957-04-13  1957    Unprovoked         AUSTRALIA
# 6824  1955-11-16  1955    Unprovoked  PAPUA NEW GUINEA
# 6844  1936-02-04  1936    Unprovoked         AUSTRALIA
#
#                               area  \
# 6                           Hawaii
# 10                         Florida
# 13                    North Island
# 19                    South Island
# 22                      California
# ...                            ...
# 6816  Between Hawaii & Wake Island
# 6817               New South Wales
# 6818                 Torres Strait
# 6824              Central Province
# 6844               New South Wales
#
#                                                location  \
# 6                               Marine Corps Base, Oahu
# 10                                         Ormond Beach
# 13                                        Pauanui Beach
# 19                                          Oreti Beach
# 22                          Oceanside, San Diego County
# ...                                                 ...
# 6816                    600 miles northwest of Honolulu
# 6817                                    Brunswick Heads
# 6818                Thursday Island Harbour, Queensland
# 6824  Kalautu Village, Baibara at the mouth of Oibad...
# 6844                                South Steyne, Manly
#
#                                                activity  \
# 6                                               Surfing
# 10                                             Swimming
# 13                                              Surfing
# 19                                      Boogie boarding
# 22                                             Paddling
# ...                                                 ...
# 6816  U.S. Airforce C124 enroute from Hickham Air Ba...
# 6817                                       Body surfing
# 6818       Swimming between  anchored  pearling luggers
# 6824                                           Swimming
# 6844                                           Swimming
#
#                                name sex  age  \
# 6                 Parker Blanchette   M   14
# 10                    Jordan Hooper   M   17
# 13                     Nick Minogue   M   60
# 19                           female   F   17
# 22                      Julie Wolfe   F   57
# ...                             ...  ..  ...
# 6816  Captain Jonathan Brown, pilot   M   31
# 6817                Brian Henderson   M   14
# 6818                 Tuisafua Nomoa   M   22
# 6824                       Niu Bodu   M    8
# 6844                    David Paton   M   14
#
#                                                  injury fatal_y_n  \
# 6                          Lacerations to shin and calf         N
# 10                                       Minor injuries         N
# 13                       Minor injury, surfboard bitten         N
# 19                                        Gash to thigh         N
# 22    No injury to occupant, outrigger canoe and pad...         N
# ...                                                 ...       ...
# 6816                               Left shoulder bitten         N
# 6817      Laceration to left ankle, heel and little toe         N
# 6818              Left arm bitten, surgically amputated         N
# 6824                                 Right thigh bitten         N
# 6844  FATAL, taken by shark, body not recovered. Twe...         Y
#
#                                               Species_1  Species_2 Species_3  \
# 6                                          5.5 ft shark       None      None
# 10                                       Blacktip shark   6' to 7'      None
# 13                                          White shark       None      None
# 19    Reported as shark bite but injury caused by st...       None      None
# 22                                          White shark       None      None
# ...                                                 ...        ...       ...
# 6816               Sharks averaged 1.8 m [6'] in length       None      None
# 6817                                            Unknown       None      None
# 6818  Shark seen feeding on turtle scraps thrown ove...       None      None
# 6824                                    Wobbegong shark       None      None
# 6844                                        White shark       None      None
#
#      Species_4
# 6         None
# 10        None
# 13        None
# 19        None
# 22        None
# ...        ...
# 6816      None
# 6817      None
# 6818      None
# 6824      None
# 6844      None
#
# [1621 rows x 16 columns]

# %%
#change date data type from object to date/time format
clean_data_df['date']=pd.to_datetime(clean_data_df['date'], format='%Y-%m-%d')

# %%
# verify datatypes to make sure date/time format is reflected
clean_data_df.dtypes
# Out:
# date         datetime64[ns]
# year                 object
# type                 object
# country              object
# area                 object
# location             object
# activity             object
# name                 object
# sex                  object
# age                   Int64
# injury               object
# fatal_y_n            object
# Species_1            object
# Species_2            object
# Species_3            object
# Species_4            object
# dtype: object

# %%
# reprint dataframe
clean_data_df
# Out:
#            date  year          type           country  \
# 6    2021-05-03  2021    Unprovoked               USA
# 10   2020-10-31  2020    Unprovoked               USA
# 13   2020-02-22  2020    Unprovoked       NEW ZEALAND
# 19   2019-01-29  2019       Invalid       NEW ZEALAND
# 22   2018-06-25  2018    Watercraft               USA
# ...         ...   ...           ...               ...
# 6816 1958-07-04  1958  Sea Disaster     PACIFIC OCEAN
# 6817 1958-01-19  1958    Unprovoked         AUSTRALIA
# 6818 1957-04-13  1957    Unprovoked         AUSTRALIA
# 6824 1955-11-16  1955    Unprovoked  PAPUA NEW GUINEA
# 6844 1936-02-04  1936    Unprovoked         AUSTRALIA
#
#                               area  \
# 6                           Hawaii
# 10                         Florida
# 13                    North Island
# 19                    South Island
# 22                      California
# ...                            ...
# 6816  Between Hawaii & Wake Island
# 6817               New South Wales
# 6818                 Torres Strait
# 6824              Central Province
# 6844               New South Wales
#
#                                                location  \
# 6                               Marine Corps Base, Oahu
# 10                                         Ormond Beach
# 13                                        Pauanui Beach
# 19                                          Oreti Beach
# 22                          Oceanside, San Diego County
# ...                                                 ...
# 6816                    600 miles northwest of Honolulu
# 6817                                    Brunswick Heads
# 6818                Thursday Island Harbour, Queensland
# 6824  Kalautu Village, Baibara at the mouth of Oibad...
# 6844                                South Steyne, Manly
#
#                                                activity  \
# 6                                               Surfing
# 10                                             Swimming
# 13                                              Surfing
# 19                                      Boogie boarding
# 22                                             Paddling
# ...                                                 ...
# 6816  U.S. Airforce C124 enroute from Hickham Air Ba...
# 6817                                       Body surfing
# 6818       Swimming between  anchored  pearling luggers
# 6824                                           Swimming
# 6844                                           Swimming
#
#                                name sex  age  \
# 6                 Parker Blanchette   M   14
# 10                    Jordan Hooper   M   17
# 13                     Nick Minogue   M   60
# 19                           female   F   17
# 22                      Julie Wolfe   F   57
# ...                             ...  ..  ...
# 6816  Captain Jonathan Brown, pilot   M   31
# 6817                Brian Henderson   M   14
# 6818                 Tuisafua Nomoa   M   22
# 6824                       Niu Bodu   M    8
# 6844                    David Paton   M   14
#
#                                                  injury fatal_y_n  \
# 6                          Lacerations to shin and calf         N
# 10                                       Minor injuries         N
# 13                       Minor injury, surfboard bitten         N
# 19                                        Gash to thigh         N
# 22    No injury to occupant, outrigger canoe and pad...         N
# ...                                                 ...       ...
# 6816                               Left shoulder bitten         N
# 6817      Laceration to left ankle, heel and little toe         N
# 6818              Left arm bitten, surgically amputated         N
# 6824                                 Right thigh bitten         N
# 6844  FATAL, taken by shark, body not recovered. Twe...         Y
#
#                                               Species_1  Species_2 Species_3  \
# 6                                          5.5 ft shark       None      None
# 10                                       Blacktip shark   6' to 7'      None
# 13                                          White shark       None      None
# 19    Reported as shark bite but injury caused by st...       None      None
# 22                                          White shark       None      None
# ...                                                 ...        ...       ...
# 6816               Sharks averaged 1.8 m [6'] in length       None      None
# 6817                                            Unknown       None      None
# 6818  Shark seen feeding on turtle scraps thrown ove...       None      None
# 6824                                    Wobbegong shark       None      None
# 6844                                        White shark       None      None
#
#      Species_4
# 6         None
# 10        None
# 13        None
# 19        None
# 22        None
# ...        ...
# 6816      None
# 6817      None
# 6818      None
# 6824      None
# 6844      None
#
# [1621 rows x 16 columns]

# %%
# look at count of species in list again
clean_data_df['Species_1'].value_counts().head(200)
# Out:
# Species_1
# White shark                                      260
# Tiger shark                                      136
# Unknown                                          131
# Bull shark                                        73
# Bronze whaler shark                               29
#                                                 ...
# Possibly a 1' to 3' blacktip or spinner shark      1
# 14' to 16' white shark                             1
# 5.5 m [18'] shark                                  1
# Bronze whaler or tiger shark                       1
# 43 shark                                           1
# Name: count, Length: 200, dtype: int64

# %%
# remove unnecessary column
del clean_data_df['Species_2']

# %%
# remove unnecessary column
del clean_data_df['Species_3']

# %%
# remove unnecessary column
del clean_data_df['Species_4']

# %%
# reprint dataframe
clean_data_df
# Out:
#            date  year          type           country  \
# 6    2021-05-03  2021    Unprovoked               USA
# 10   2020-10-31  2020    Unprovoked               USA
# 13   2020-02-22  2020    Unprovoked       NEW ZEALAND
# 19   2019-01-29  2019       Invalid       NEW ZEALAND
# 22   2018-06-25  2018    Watercraft               USA
# ...         ...   ...           ...               ...
# 6816 1958-07-04  1958  Sea Disaster     PACIFIC OCEAN
# 6817 1958-01-19  1958    Unprovoked         AUSTRALIA
# 6818 1957-04-13  1957    Unprovoked         AUSTRALIA
# 6824 1955-11-16  1955    Unprovoked  PAPUA NEW GUINEA
# 6844 1936-02-04  1936    Unprovoked         AUSTRALIA
#
#                               area  \
# 6                           Hawaii
# 10                         Florida
# 13                    North Island
# 19                    South Island
# 22                      California
# ...                            ...
# 6816  Between Hawaii & Wake Island
# 6817               New South Wales
# 6818                 Torres Strait
# 6824              Central Province
# 6844               New South Wales
#
#                                                location  \
# 6                               Marine Corps Base, Oahu
# 10                                         Ormond Beach
# 13                                        Pauanui Beach
# 19                                          Oreti Beach
# 22                          Oceanside, San Diego County
# ...                                                 ...
# 6816                    600 miles northwest of Honolulu
# 6817                                    Brunswick Heads
# 6818                Thursday Island Harbour, Queensland
# 6824  Kalautu Village, Baibara at the mouth of Oibad...
# 6844                                South Steyne, Manly
#
#                                                activity  \
# 6                                               Surfing
# 10                                             Swimming
# 13                                              Surfing
# 19                                      Boogie boarding
# 22                                             Paddling
# ...                                                 ...
# 6816  U.S. Airforce C124 enroute from Hickham Air Ba...
# 6817                                       Body surfing
# 6818       Swimming between  anchored  pearling luggers
# 6824                                           Swimming
# 6844                                           Swimming
#
#                                name sex  age  \
# 6                 Parker Blanchette   M   14
# 10                    Jordan Hooper   M   17
# 13                     Nick Minogue   M   60
# 19                           female   F   17
# 22                      Julie Wolfe   F   57
# ...                             ...  ..  ...
# 6816  Captain Jonathan Brown, pilot   M   31
# 6817                Brian Henderson   M   14
# 6818                 Tuisafua Nomoa   M   22
# 6824                       Niu Bodu   M    8
# 6844                    David Paton   M   14
#
#                                                  injury fatal_y_n  \
# 6                          Lacerations to shin and calf         N
# 10                                       Minor injuries         N
# 13                       Minor injury, surfboard bitten         N
# 19                                        Gash to thigh         N
# 22    No injury to occupant, outrigger canoe and pad...         N
# ...                                                 ...       ...
# 6816                               Left shoulder bitten         N
# 6817      Laceration to left ankle, heel and little toe         N
# 6818              Left arm bitten, surgically amputated         N
# 6824                                 Right thigh bitten         N
# 6844  FATAL, taken by shark, body not recovered. Twe...         Y
#
#                                               Species_1
# 6                                          5.5 ft shark
# 10                                       Blacktip shark
# 13                                          White shark
# 19    Reported as shark bite but injury caused by st...
# 22                                          White shark
# ...                                                 ...
# 6816               Sharks averaged 1.8 m [6'] in length
# 6817                                            Unknown
# 6818  Shark seen feeding on turtle scraps thrown ove...
# 6824                                    Wobbegong shark
# 6844                                        White shark
#
# [1621 rows x 13 columns]

# %%
# review tail of dataframe
clean_data_df['Species_1'].value_counts().tail(10)
# Out:
# Species_1
# Thought to involve a blacktip shark                                        1
# Mako shark (tooth fragments recovered)                                     1
# 150-lb shark                                                               1
# Small shark                                                                1
# Though to involve a white shark                                            1
# 1.3 to 1.6 m shark                                                         1
# 6 m [20'] shark                                                            1
# 3'  shark                                                                  1
# 3.7 m to 4.3 m [12' to 14'] white shark                                    1
# Shark seen feeding on turtle scraps thrown overboard prior to incident.    1
# Name: count, dtype: int64

# %%
# create white shark dataframe
white_shark_df = clean_data_df.loc[clean_data_df['Species_1'] =='White shark' ]
white_shark_df
# Out:
#            date  year        type       country                     area  \
# 13   2020-02-22  2020  Unprovoked   NEW ZEALAND             North Island
# 22   2018-06-25  2018  Watercraft           USA               California
# 24   2017-07-07  2017  Unprovoked  SOUTH AFRICA    Eastern Cape Province
# 37   2015-07-02  2015  Unprovoked     AUSTRALIA          New South Wales
# 45   2014-08-01  2014  Unprovoked  SOUTH AFRICA    Western Cape Province
# ...         ...   ...         ...           ...                      ...
# 6679 2015-07-03  2015  Unprovoked     AUSTRALIA          New South Wales
# 6725 2002-09-13  2002  Unprovoked  SOUTH AFRICA    Western Cape Province
# 6797 1963-02-08  1963  Unprovoked          FIJI  Lomaiviti  Island Group
# 6808 1960-04-24  1960  Unprovoked           USA               California
# 6844 1936-02-04  1936  Unprovoked     AUSTRALIA          New South Wales
#
#                           location  \
# 13                   Pauanui Beach
# 22     Oceanside, San Diego County
# 24        Nahoon Reef, East London
# 37                    East Ballina
# 45                      Muizenberg
# ...                            ...
# 6679                   Lennox Head
# 6725          Glencairn, False Bay
# 6797  Taibaisa Passage, Gau Island
# 6808   Tomales Point, Marin County
# 6844           South Steyne, Manly
#
#                                             activity                    name  \
# 13                                           Surfing            Nick Minogue
# 22                                          Paddling             Julie Wolfe
# 24                                           Surfing               Zoe Stein
# 37                                     Body boarding                Matt Lee
# 45                                           Surfing        Matthew Smithers
# ...                                              ...                     ...
# 6679                                         Surfing           Michael Hoile
# 6725                                     Surf skiing  Paul Mauger (or Major)
# 6797                                    Spearfishing          Jone Waiteatei
# 6808  Free diving for abalone diving but at surface)        Frank I. Gilbert
# 6844                                        Swimming             David Paton
#
#      sex  age                                             injury fatal_y_n  \
# 13     M   60                     Minor injury, surfboard bitten         N
# 22     F   57  No injury to occupant, outrigger canoe and pad...         N
# 24     F   13                     No injury, shark bit surfboard         N
# 37     M   32                 Significant injuries to lower legs         N
# 45     M   20                         Lower limbs & thigh bitten         N
# ...   ..  ...                                                ...       ...
# 6679   M   52                     No injury, shark bit surfboard         N
# 6725   M   47                                          No injury         N
# 6797   M   28                                    Left arm bitten         N
# 6808   M   48                             Foot & swim fin bitten         N
# 6844   M   14  FATAL, taken by shark, body not recovered. Twe...         Y
#
#         Species_1
# 13    White shark
# 22    White shark
# 24    White shark
# 37    White shark
# 45    White shark
# ...           ...
# 6679  White shark
# 6725  White shark
# 6797  White shark
# 6808  White shark
# 6844  White shark
#
# [260 rows x 13 columns]

# %%
# create tiger shark dataframe
tiger_shark_df = clean_data_df.loc[clean_data_df['Species_1'] =='Tiger shark' ]
tiger_shark_df
# Out:
#            date  year          type    country           area  \
# 36   2015-10-09  2015    Unprovoked        USA         Hawaii
# 51   2013-06-18  2013    Unprovoked        USA         Hawaii
# 54   2013-03-12  2013    Unprovoked    JAMAICA  St. Catherine
# 84   2006-03-18  2006    Unprovoked       FIJI      Vitu Levu
# 94   2000-09-08  2000    Unprovoked    REUNION   Saint-Pierre
# ...         ...   ...           ...        ...            ...
# 6668 2017-10-09  2017    Unprovoked        USA         Hawaii
# 6739 1997-02-28  1997    Unprovoked  AUSTRALIA     Queensland
# 6751 1992-11-05  1992    Unprovoked        USA         Hawaii
# 6752 1992-10-22  1992    Unprovoked        USA         Hawaii
# 6772 1983-07-26  1983  Sea Disaster  AUSTRALIA     Queensland
#
#                                                location  \
# 36                                      Leftovers, Oahu
# 51                                Kona Coast State Park
# 54                              Pillikin Red Light area
# 84                                             Sigatoka
# 94                                        Pic du Diable
# ...                                                 ...
# 6668                     Davidsons Beach, Kekaha, Kauai
# 6739                                 Whitsunday Passage
# 6751                           Kea'au Beach Park, O'ahu
# 6752                                    Lanaikea, O'ahu
# 6772  Off Lodestone Reef, Great Barrier Reef, north ...
#
#                            activity                   name sex  age  \
# 36                          Surfing             Colin Cook   M   25
# 51                         Swimming         James Kerrigan   M   28
# 54                     Spearfishing           George Facey   M   68
# 84                          Surfing               Paul Sue   M   21
# 94                          Surfing             Karim Maan   M   27
# ...                             ...                    ...  ..  ...
# 6668                        Surfing            Mitch Milan   M   54
# 6739                   Scuba diving           Gerald Rauch   M   30
# 6751                  Body boarding      Aaron  A. Romento   M   18
# 6752                        Surfing  Rick (Eric) Gruzinsky   M   28
# 6772  Swimming from the New Venture       Linda Ann Horton   F   21
#
#                                                  injury fatal_y_n    Species_1
# 36    Left leg severed below the knee, defense injur...         N  Tiger shark
# 51                            Right thigh & calf bitten         N  Tiger shark
# 54                                                FATAL         Y  Tiger shark
# 84                            Lacerations to right hand         N  Tiger shark
# 94                                      Left arm bitten         N  Tiger shark
# ...                                                 ...       ...          ...
# 6668                           Lacerations to left hand         N  Tiger shark
# 6739                                    Left arm bitten         N  Tiger shark
# 6751                Right leg severely lacerated  FATAL         Y  Tiger shark
# 6752  Chest & arm bruised & scratched, 15 crescent-s...         N  Tiger shark
# 6772  FATAL, shark seized her by the chest and took ...         Y  Tiger shark
#
# [136 rows x 13 columns]

# %%
# create unknown shark dataframe
unknown_shark_df = clean_data_df.loc[clean_data_df['Species_1'] =='Unknown' ]
unknown_shark_df
# Out:
#            date  year        type    country             area  \
# 63   2011-08-31  2011  Unprovoked        USA          Florida
# 82   2007-08-25  2007  Unprovoked        USA          Florida
# 104  1998-05-16  1998  Unprovoked        USA          Florida
# 159  1964-09-07  1964  Unprovoked     TAIWAN  Northern Taiwan
# 168  1961-12-13  1961  Unprovoked  AUSTRALIA    Torres Strait
# ...         ...   ...         ...        ...              ...
# 6691 2011-01-31  2011  Unprovoked     MEXICO     Quintana Roo
# 6728 2001-09-24  2001    Provoked        USA          Florida
# 6733 1999-08-16  1999  Unprovoked        USA   South Carolina
# 6770 1985-09-05  1985     Invalid        USA          Florida
# 6817 1958-01-19  1958  Unprovoked  AUSTRALIA  New South Wales
#
#                                       location  \
# 63             Crescent Beach St. Johns County
# 82            New Smyrna Beach, Volusia County
# 104                  Pecks Lake, Martin County
# 159                               Tamsui Beach
# 168          Horn Island, near Thursday Island
# ...                                        ...
# 6691                                    Cancun
# 6728               Ponce Inlet, Volusia County
# 6733  Grand Strand, Myrtle Beach, Horry County
# 6770        Fort Pierce Inlet, St Lucie County
# 6817                           Brunswick Heads
#
#                                                activity  \
# 63                                              Surfing
# 82                                              Surfing
# 104                                            Swimming
# 159                                            Swimming
# 168                 Swimming with other crew near wharf
# ...                                                 ...
# 6691                                           Swimming
# 6728  Surfing, fell off surfboard & stepped on the s...
# 6733                         Lying prone in 2' of water
# 6770                                           Swimming
# 6817                                       Body surfing
#
#                                                    name sex  age  \
# 63                                      Shane Lancaster   M   19
# 82                                         Taylor Smith   M   27
# 104                                   Janelle Dickinson   F   14
# 159                                        LO Chiu-yang   M   20
# 168   George “Jimmy” Stevens, aborgine from the lugg...   M   17
# ...                                                 ...  ..  ...
# 6691                                       Nicole Moore   F   38
# 6728                                               male   M   21
# 6733                        Christopher (Will)  Handley   M   10
# 6770                                       Jeff Justice   M   17
# 6817                                    Brian Henderson   M   14
#
#                                                  injury fatal_y_n Species_1
# 63                             Lacerations to lower leg         N   Unknown
# 82                           6 lacerations to left hand         N   Unknown
# 104                                 Ankle & foot bitten         N   Unknown
# 159                         Right thigh &  elbow bitten         N   Unknown
# 168                       Right thigh and leg lacerated         N   Unknown
# ...                                                 ...       ...       ...
# 6691                Leg, forearm & hand severely bitten         N   Unknown
# 6728  PROVOKED INCIDENT Several small lacerations on...         N   Unknown
# 6733  Ear lacerated, cuts on scalp, back, arm & shou...         N   Unknown
# 6770                                 Found to be a hoax   UNKNOWN   Unknown
# 6817      Laceration to left ankle, heel and little toe         N   Unknown
#
# [131 rows x 13 columns]

# %%
# create bull shark dataframe
bull_shark_df = clean_data_df.loc[clean_data_df['Species_1'] =='Bull shark' ]
bull_shark_df
# Out:
#            date  year        type        country                 area  \
# 39   2015-06-01  2015  Unprovoked        REUNION              Le Port
# 68   2009-12-20  2009  Unprovoked      AUSTRALIA           Queensland
# 262  2021-01-13  2021  Unprovoked      AUSTRALIA    Western Australia
# 305  2011-06-28  2011  Unprovoked   SOUTH AFRICA        KwaZulu-Natal
# 516  2020-09-20  2020  Unprovoked            USA              Florida
# ...         ...   ...         ...            ...                  ...
# 6440 2015-06-07  2015  Unprovoked            USA              Florida
# 6460 2008-06-26  2011  Unprovoked            USA       North Carolina
# 6472 2008-04-26  2008  Unprovoked  NEW CALEDONIA       North Province
# 6690 2011-03-23  2011  Unprovoked      AUSTRALIA      New South Wales
# 6699 2009-01-25  2009  Unprovoked           CUBA  Guantanamo Province
#
#                                             location             activity  \
# 39                                           Folette              Surfing
# 68                                       Lamont Reef         Spearfishing
# 262                                  Blackwall Reach             Swimming
# 305                                     Aliwal Shoal         Scuba diving
# 516                 Sombero Key Light, Monroe County           Snorkeling
# ...                                              ...                  ...
# 6440  Lori Wilson Park, Cocoa Beach, Brevard  County              Playing
# 6460              North Topsail Beach, Onslow County  Playing in the surf
# 6472                                       Poindimié             Swimming
# 6690                                     Crowdy Head              Surfing
# 6699                                  Guantanamo Bay         Spearfishing
#
#                      name sex  age                                     injury  \
# 39        Eddy Chaussalet   M   47                        Left forearm bitten
# 68          John Pengelly   M   18              Lacerations to hand & forearm
# 262      Cameron Wrathall   M   54        Severe injury to leg and broken him
# 305         Paolo Stanchi   M   22  Severe lacerations to hands and  left leg
# 516   Andrew Charles Eddy   M   30                    Severe bite to shoulder
# ...                   ...  ..  ...                                        ...
# 6440       Lucas Vertullo   M   11                  Lacerations to right calf
# 6460   Cassidy Cartwright   F   10                               Ankle bitten
# 6472       Olivier Vilain   M   32                   Lacerations to left foot
# 6690        David Pearson   M   48              Severe injury to left forearm
# 6699           John Emory   M   15       Severe lacerations to lower left leg
#
#      fatal_y_n   Species_1
# 39           N  Bull shark
# 68           N  Bull shark
# 262          N  Bull shark
# 305          N  Bull shark
# 516          N  Bull shark
# ...        ...         ...
# 6440         N  Bull shark
# 6460         N  Bull shark
# 6472         N  Bull shark
# 6690         N  Bull shark
# 6699         N  Bull shark
#
# [73 rows x 13 columns]

# %%
# create bronze whaler shark dataframe
bronze_whaler_shark_df = clean_data_df.loc[clean_data_df['Species_1'] =='Bronze whaler' ]
bronze_whaler_shark_df
# Out:
#            date  year        type    country             area      location  \
# 974  2022-08-31  2022  Unprovoked  AUSTRALIA  New South Wales         Avoca
# 5808 1982-12-26  1982  Unprovoked  AUSTRALIA  New South Wales  Suffolk Park
#
#      activity           name sex  age  \
# 974   Surfing     Sunni Pace   M   14
# 5808  Surfing  Paul Fletcher   M   27
#
#                                        injury fatal_y_n      Species_1
# 974   Puncture wounds to right hand & forearm         N  Bronze whaler
# 5808              No injury, surfboard bitten         N  Bronze whaler

# %%
# create blacktip shark dataframe
blacktip_shark_df = clean_data_df.loc[clean_data_df['Species_1'] =='Blacktip shark' ]
blacktip_shark_df
# Out:
#            date  year        type              country               area  \
# 10   2020-10-31  2020  Unprovoked                  USA            Florida
# 428  1962-09-30  1962  Unprovoked  BRITISH WEST INDIES  Grand Turk Island
# 544  2014-10-05  2014  Unprovoked                  USA            Florida
# 774  2016-05-18  2016  Unprovoked                  USA            Florida
# 976  2021-08-02  2021  Unprovoked                  USA           Maryland
# 1023 2013-02-10  2013  Unprovoked                  USA            Florida
# 1067 2000-10-06  2000  Unprovoked                  USA            Florida
# 1166 1947-03-09  1947  Unprovoked         SOUTH AFRICA      KwaZulu-Natal
# 1230 2022-03-09  2022    Provoked                  USA            Florida
# 1314 2000-08-12  2000  Unprovoked                  USA            Florida
# 1790 1997-07-14  1997  Unprovoked                  USA     South Carolina
# 2224 2020-10-07  2020  Unprovoked                  USA            Florida
# 3205 2015-03-16  2015  Unprovoked     FRENCH POLYNESIA          Bora Bora
# 3242 2007-10-06  2007  Unprovoked                  USA            Florida
# 3732 2011-06-12  2011  Unprovoked                  USA            Florida
# 4282 1999-07-04  1999  Unprovoked                  USA            Florida
# 4473 2012-06-14  2012  Unprovoked                  USA     South Carolina
# 4487 2009-05-12  2009    Provoked                 GUAM       North Region
# 4521 2000-06-10  2000  Unprovoked                  USA              Texas
# 4694 2016-01-05  2016  Unprovoked            AUSTRALIA         Queensland
# 4695 2015-10-04  2015  Unprovoked                  USA            Florida
# 5025 1986-01-12  1986  Unprovoked                  USA            Florida
# 5506 2001-08-18  2001  Unprovoked                  USA            Florida
# 5685 2018-09-23  2018  Unprovoked              BAHAMAS      Abaco Islands
# 5702 2015-09-29  2015  Unprovoked                  USA            Florida
# 5710 2014-10-05  2014  Unprovoked                  USA            Florida
# 5931 2020-08-10  2020    Provoked                  USA            Florida
# 6415 2021-03-18  2021  Unprovoked                  USA            Florida
#
#                                                location  \
# 10                                         Ormond Beach
# 428                                            Long Cay
# 544                    New Smyrna Beach, Volusia County
# 774                       Ponte Vedra, St. Johns County
# 976                        Ocean City, Worcester County
# 1023                        Stuart Rocks, Martin County
# 1067                   New Smyrna Beach, Volusia County
# 1166                         Country Club Beach, Durban
# 1230                   New Smyrna Beach, Volusia County
# 1314                    St. Augustine, St. Johns County
# 1790                         Myrtle Beach, Horry County
# 2224                     Miami Beach, Miami-Dade County
# 3205                                               Anau
# 3242  Playalinda Beach, Canaveral National Seashore,...
# 3732               Off Jupiter Inlet, Palm Beach County
# 4282                  Pensacola  Beach, Escambia County
# 4473                         Myrtle Beach, Horry County
# 4487                                     Ritidian Point
# 4521                J.P. Luby Surf Park, Corpus Christi
# 4694                                       Heron Island
# 4695                   New Smyrna Beach, Volusia County
# 5025    Singer Island, Riviera Beach, Palm Beach County
# 5506                   New Smyrna Beach, Volusia County
# 5685                                       Treasure Cay
# 5702                    Vilano Beach, St.  Johns County
# 5710                   New Smyrna Beach, Volusia County
# 5931            Off Gasparilla Island, Charlotte County
# 6415                      Juno Beach, Palm Beach County
#
#                           activity                        name sex  age  \
# 10                        Swimming               Jordan Hooper   M   17
# 428                   Spearfishing              Wesley Vickrey   M   24
# 544                        Surfing                  Kevin Ross   M   29
# 774                       Swimming                 Mark Wilson   M   48
# 976                       Swimming           Jordan Prushinski   F   12
# 1023                       Surfing               Cole Taschman   M   16
# 1067                       Surfing                Austin White   M   23
# 1166                Treading water  Gabriel Botha, a lifesaver   M   22
# 1230                       Fishing                        male   M   21
# 1314                      Standing              Margaret White   F   44
# 1790                      Standing                Flint Cowden   M   50
# 2224                  Body Surfing                 Mark Bowden   M   31
# 3205           Hand feeding sharks                        male   M    9
# 3242                       Surfing                        E.H.   M   16
# 3732                  Scuba diving                 Daniel Webb   M   28
# 4282  Wading in school of baitfish              Lisa Alexander   F   30
# 4473                      Swimming             Jordon Garosalo   M   16
# 4487                  Spearfishing      Jonathan Leon Guerrero   M   27
# 4521                       Surfing             Kenny Alexander   M   17
# 4694                        Wading               Nicolas Davis   M   11
# 4695                       Surfing           Phillip Tarasovic   M   14
# 5025                       Surfing         Christopher Blissel   M   22
# 5506                       Surfing                Dylan Feindt   M   19
# 5685                  Spearfishing                Maggie Ewing   F   32
# 5702                       Surfing         David Morrison, Jr.   M   22
# 5710                       Surfing             Hilton Mantooth   M   15
# 5931                       Fishing                        male   M   55
# 6415                        Wading                Bryce Albert   M   20
#
#                                                  injury fatal_y_n  \
# 10                                       Minor injuries         N
# 428                 Left thigh & hand & speargun bitten         N
# 544                                         Foot bitten         N
# 774                                        Ankle bitten         N
# 976   Lacerations and puncture wounds to lower left leg         N
# 1023                          Lacerations to right hand         N
# 1067                                  Fingers lacerated         N
# 1166              Lacerations on buttock  &  right foot         N
# 1230  M inor injuries to knee and calf of left leg  ...         N
# 1314                       Severely bitten on lower leg         N
# 1790                                   Left calf bitten         N
# 2224                            Laceration to lower leg         N
# 3205                                        Hand bitten         N
# 3242                   Severe lacerations to right hand         N
# 3732                          Lacerations to right calf         N
# 4282                          Lacerations knee to ankle         N
# 4473                           Laceration to right foot         N
# 4487    Speared shark bit his forearm PROVOKED INCIDENT         N
# 4521                                     Foot lacerated         N
# 4694                           Laceration to right calf         N
# 4695                    Severe lacerations to left hand         N
# 5025                       Puncture wounds to both feet         N
# 5506                                  Left ankle bitten         N
# 5685                             Lacerations to fingers         N
# 5702  Laceration to heel, puncture wounds to dorsum ...         N
# 5710                                        Foot bitten         N
# 5931  Injury to left forearm by hooked shark PROVOKE...         N
# 6415                                Left forearm bitten         N
#
#            Species_1
# 10    Blacktip shark
# 428   Blacktip shark
# 544   Blacktip shark
# 774   Blacktip shark
# 976   Blacktip shark
# 1023  Blacktip shark
# 1067  Blacktip shark
# 1166  Blacktip shark
# 1230  Blacktip shark
# 1314  Blacktip shark
# 1790  Blacktip shark
# 2224  Blacktip shark
# 3205  Blacktip shark
# 3242  Blacktip shark
# 3732  Blacktip shark
# 4282  Blacktip shark
# 4473  Blacktip shark
# 4487  Blacktip shark
# 4521  Blacktip shark
# 4694  Blacktip shark
# 4695  Blacktip shark
# 5025  Blacktip shark
# 5506  Blacktip shark
# 5685  Blacktip shark
# 5702  Blacktip shark
# 5710  Blacktip shark
# 5931  Blacktip shark
# 6415  Blacktip shark

# %%
# create raggedtooh shark dataframe
raggedtooth_shark_df = clean_data_df.loc[clean_data_df['Species_1'] =='Raggedtooth shark' ]
raggedtooth_shark_df
# Out:
#            date  year        type       country                   area  \
# 137  1983-12-21  1983  Unprovoked  SOUTH AFRICA  Eastern Cape Province
# 334  2006-04-09  2006  Unprovoked  SOUTH AFRICA  Eastern Cape Province
# 390  1986-02-06  1986  Unprovoked  SOUTH AFRICA  Western Cape Province
# 628  1983-04-12  1983  Unprovoked  SOUTH AFRICA  Eastern Cape Province
# 1041 2006-12-06  2006    Provoked  SOUTH AFRICA          KwaZulu-Natal
# 1114 1981-05-20  1981  Unprovoked  SOUTH AFRICA  Eastern Cape Province
# 1262 2015-01-03  2015  Unprovoked  SOUTH AFRICA  Eastern Cape Province
# 1353 1984-01-05  1984  Unprovoked  SOUTH AFRICA  Eastern Cape Province
# 1358 1981-05-10  1981  Unprovoked  SOUTH AFRICA  Eastern Cape Province
# 1879 1932-01-01  1932  Unprovoked  SOUTH AFRICA  Eastern Cape Province
# 2329 1982-01-29  1982  Unprovoked  SOUTH AFRICA  Eastern Cape Province
# 2339 1974-04-20  1974  Unprovoked  SOUTH AFRICA  Western Cape Province
# 2998 2008-12-10  2008    Provoked  SOUTH AFRICA  Western Cape Province
# 3060 1985-01-27  1985  Unprovoked  SOUTH AFRICA  Western Cape Province
# 3781 1995-02-19  1995  Unprovoked  SOUTH AFRICA  Eastern Cape Province
# 3804 1986-02-07  1986  Unprovoked  SOUTH AFRICA  Eastern Cape Province
# 4013 2004-10-09  2004  Unprovoked  SOUTH AFRICA  Eastern Cape Province
# 4496 2005-11-15  2005    Provoked  SOUTH AFRICA  Eastern Cape Province
# 5037 1980-01-10  1980  Unprovoked  SOUTH AFRICA  Eastern Cape Province
# 5056 1964-12-25  1964  Unprovoked  SOUTH AFRICA  Eastern Cape Province
# 5488 2006-02-08  2006  Unprovoked  SOUTH AFRICA  Eastern Cape Province
# 5491 2005-05-25  2005  Unprovoked  SOUTH AFRICA  Eastern Cape Province
# 5493 2004-11-27  2004  Unprovoked  SOUTH AFRICA  Eastern Cape Province
# 6191 2013-03-16  2013    Provoked  SOUTH AFRICA  Western Cape Province
# 6539 1970-06-15  1970    Provoked  SOUTH AFRICA          KwaZulu-Natal
#
#                                                location  \
# 137                                              Nahoon
# 334                                     St. Francis Bay
# 390                                            Arniston
# 628                                           Bonza Bay
# 1041                                         Cape Vidal
# 1114                                             Nahoon
# 1262                                 Chintsa East Beach
# 1353                                        Port Alfred
# 1358                                       King’s Beach
# 1879                     Kowie River Mouth, Port Alfred
# 2329                                          Mpekeweni
# 2339                                           Arniston
# 2998                                    Plettenberg Bay
# 3060                                         Struisbaai
# 3781                                       Kidd’s Beach
# 3804                       King's Beach, Port Elizabeth
# 4013                                      Jeffrey’s Bay
# 4496                                          Aston Bay
# 5037                                       King’s Beach
# 5056                                        Port Alfred
# 5488                                Nahoon, East London
# 5491                                    Kei River Mouth
# 5493                                Nahoon, East London
# 6191                                            De Mond
# 6539  Shark tank, Oceanographic Research Institute, ...
#
#                                    activity                   name sex  age  \
# 137                                Swimming        Jack Heydenrych   M   47
# 334                           Body boarding          Stuart Duffie   M   15
# 390                            Spearfishing       Michael Taljaard   M   29
# 628                                 Fishing        Peter S. Venter   M   27
# 1041                                Fishing       Peter Willoughby   M   25
# 1114                                Surfing              Mark Jury   M   27
# 1262                                Surfing           Jason Krafft   M   15
# 1353                               Swimming         Robert Tennent   M   14
# 1358                                Surfing            John Dunser   M   19
# 1879  Collecting fish by lamplight in gully        Manning Samuels   M   23
# 2329                               Swimming  Jeffrey Phillips-Page   M   20
# 2339                           Spearfishing          Andre Hartman   M   22
# 2998                                Fishing            Luke Parker   M   15
# 3060                               Swimming           Marius Botha   M   15
# 3781                               Swimming         Johan Deetlefs   M   22
# 3804                               Swimming           Johan Fourie   M   46
# 4013                                Surfing             Wayne Monk   M   34
# 4496                     Fishing for sharks            Ivan Gerger   M   32
# 5037                               Swimming            Andy Austin   M   25
# 5056                               Swimming         W. A. Strijdom   M   19
# 5488                                Surfing           Jason Noades   M   15
# 5491                                Surfing          Jay Catherall   M   32
# 5493                                Surfing        Llewellyn Maske   M   20
# 6191              Fishing - 'tag & release'          Kobus Koeberg   M   30
# 6539                           Scuba Diving       Anand Govindsamy   M   25
#
#                                                  injury fatal_y_n  \
# 137                                      Shin lacerated         N
# 334                                          Leg bitten         N
# 390                            2 punctures in upper arm         N
# 628                             Puncture wounds to foot         N
# 1041  Hand, thigh & calf bitten by hooked shark PROV...         N
# 1114  Shark & board collided. No injury, but board w...         N
# 1262  Lacerations to lower left leg, puncture wounds...         N
# 1353                                        Foot bitten         N
# 1358                            No Injury, board bitten         N
# 1879        Right shin, calf and sole of foot lacerated         N
# 2329                         Right shin & toe lacerated         N
# 2339                                Left knee lacerated         N
# 2998  Lacerations to knees, thigh and hip by hooked ...         N
# 3060               Right knee, calf and ankle lacerated         N
# 3781                    Lacerations to lower leg & foot         N
# 3804                                Lower leg lacerated         N
# 4013                      Puncture wounds on right foot         N
# 4496  Lacerations to hands & right leg when he tried...         N
# 5037                           3 small punctures on arm         N
# 5056                       Hand, ankle & calf lacerated         N
# 5488                         2 bite marks on right calf         N
# 5491                     Left buttock  & legs lacerated         N
# 5493                              3 lacerations on foot         N
# 6191  Lacerations to left calf and heel from hooked ...         N
# 6539          2 cm laceration on knee PROVOKED INCIDENT         N
#
#               Species_1
# 137   Raggedtooth shark
# 334   Raggedtooth shark
# 390   Raggedtooth shark
# 628   Raggedtooth shark
# 1041  Raggedtooth shark
# 1114  Raggedtooth shark
# 1262  Raggedtooth shark
# 1353  Raggedtooth shark
# 1358  Raggedtooth shark
# 1879  Raggedtooth shark
# 2329  Raggedtooth shark
# 2339  Raggedtooth shark
# 2998  Raggedtooth shark
# 3060  Raggedtooth shark
# 3781  Raggedtooth shark
# 3804  Raggedtooth shark
# 4013  Raggedtooth shark
# 4496  Raggedtooth shark
# 5037  Raggedtooth shark
# 5056  Raggedtooth shark
# 5488  Raggedtooth shark
# 5491  Raggedtooth shark
# 5493  Raggedtooth shark
# 6191  Raggedtooth shark
# 6539  Raggedtooth shark

# %%
#create nurse shark dataframe
nurse_shark_df = clean_data_df.loc[clean_data_df['Species_1'] =='Nurse shark' ]
nurse_shark_df
# Out:
#            date  year        type  country            area  \
# 59   2012-06-15  2012    Provoked      USA         Florida
# 349  2002-03-15  2002  Unprovoked      USA         Florida
# 822  2002-08-11  2002  Unprovoked      USA         Florida
# 1489 2018-11-09  2018  Unprovoked  BAHAMAS          Exumas
# 1755 2009-07-04  2009    Provoked      USA         Florida
# 2077 1969-05-24  1969    Provoked      USA         Florida
# 2114 1958-06-26  1958    Provoked      USA         Florida
# 2855 1967-08-07  1967  Unprovoked      USA         Florida
# 2971 2013-07-28  2013  Unprovoked  BAHAMAS   Exuma Islands
# 3091 1967-06-13  1967    Provoked      USA         Florida
# 3837 1963-09-10  1963    Provoked      USA         Florida
# 3879 1939-07-16  1939    Provoked  BAHAMAS  Andros Islands
# 4490 2007-09-13  2007  Unprovoked      USA         Florida
# 5181 2016-05-15  2016    Provoked      USA         Florida
# 6013 2000-07-04  2000  Unprovoked      USA         Florida
# 6564 1958-07-02  1958    Provoked      USA         Florida
# 6660 2018-09-23  2018    Provoked     FIJI      Vanua Levu
# 6663 2018-08-15  2018  Unprovoked  BAHAMAS   Abaco Islands
#
#                                                location  \
# 59                        Summerland Key, Monroe County
# 349   Deerfield Beach (near Boca Raton), Broward County
# 822                     Vero Beach, Indian River County
# 1489                                        Compass Cay
# 1755                      Biscayne National Park, Miami
# 2077                                    Sarasota County
# 2114                         Sanibel Island, Lee County
# 2855                                      Near Key West
# 2971                                        Compass Cay
# 3091                            Key West, Monroe County
# 3837            Snapper Point Jetty, Miami, Dade County
# 3879                                          Blue Hole
# 4490              Lauderdale-by-the-Sea, Broward County
# 5181                      Boca Raton, Palm Beach County
# 6013  Artifical reef 3 miles off Manatee Beach, Mana...
# 6564                        Siesta Key, Sarasota County
# 6660                                         Cakau Levu
# 6663                         Coco Bay, Green Turtle Cay
#
#                                                activity  \
# 59                                              Fishing
# 349                                          Snorkeling
# 822                                             Surfing
# 1489                                           Swimming
# 1755                                           Swimming
# 2077                                             Diving
# 2114                                             Wading
# 2855                                       Spearfishing
# 2971                                      Cleaning fish
# 3091                                       Spearfishing
# 3837                  Spearfishing, pulled shark’s tail
# 3879  Dress diving, filming shark & pulling it throu...
# 4490                                         Snorkeling
# 5181                                    Teasing a shark
# 6013   Spearfishing, holding mesh bag with speared fish
# 6564                                        Free diving
# 6660                                             Diving
# 6663                                           Standing
#
#                         name sex   age  \
# 59                      male   M    23
# 349              Robert Land   M    39
# 822            Brad Milliken   M    15
# 1489             Asher Jones   M     8
# 1755        Carmen Dominguez   F    43
# 2077            Brian Martel   M    23
# 2114   Eric Napier Cockerill   M    59
# 2855           Donald Ritter   M    15
# 2971                    male   M    64
# 3091  Andres Puma (or Pruna)   M    26
# 3837            Robert Olsen   M    16
# 3879            E.F. MacEwan   M    38
# 4490         Brandon Chapman   M    14
# 5181                  female   F    23
# 6013        Beverly Comstock   F    55
# 6564             John Hamlin   M    20
# 6660         Timoci Ratusaki   M  <NA>
# 6663             Kate Inskip   F    56
#
#                                                  injury fatal_y_n    Species_1
# 59    Superficial injury to calf by hooked shark PRO...         N  Nurse shark
# 349                                          Arm bitten         N  Nurse shark
# 822          Lacerations on heel & dorsum of right foot         N  Nurse shark
# 1489                 Arc of shallow lacerations to back         N  Nurse shark
# 1755    Thigh injured by hooked shark PROVOKED INCIDENT         N  Nurse shark
# 2077  Laceration to buttocks Recorded as PROVOKED IN...         N  Nurse shark
# 2114  Right foot bitten when he walked into shark's ...         N  Nurse shark
# 2855                                Shark grasped thigh         N  Nurse shark
# 2971                                Bitten on left hand         N  Nurse shark
# 3091  After shark was speared & hit on head, it bit ...         N  Nurse shark
# 3837    Minor injury to left forearm  PROVOKED INCIDENT         N  Nurse shark
# 3879  Minor injury to shoulder & back PROVOKED INCIDENT         N  Nurse shark
# 4490       Minor injury, shark latched onto his abdomen         N  Nurse shark
# 5181                      Arm grabbed PROVOKED INCIDENT         N  Nurse shark
# 6013                         Lower right calf lacerated         N  Nurse shark
# 6564  He grabbed shark, it bit his leg below the kne...         N  Nurse shark
# 6660  Abrasion to leg when he kicked the shark PROVO...         N  Nurse shark
# 6663                           Injury to lower left leg         N  Nurse shark

# %%
# combine different shark dataframes together
shark_clean_data_df = pd.concat([nurse_shark_df, raggedtooth_shark_df, blacktip_shark_df, bronze_whaler_shark_df,bull_shark_df, unknown_shark_df, 
tiger_shark_df,white_shark_df], ignore_index=True)

# %%
# print new clean shark dataframe
shark_clean_data_df
# Out:
#           date  year        type       country                     area  \
# 0   2012-06-15  2012    Provoked           USA                  Florida
# 1   2002-03-15  2002  Unprovoked           USA                  Florida
# 2   2002-08-11  2002  Unprovoked           USA                  Florida
# 3   2018-11-09  2018  Unprovoked       BAHAMAS                   Exumas
# 4   2009-07-04  2009    Provoked           USA                  Florida
# ..         ...   ...         ...           ...                      ...
# 668 2015-07-03  2015  Unprovoked     AUSTRALIA          New South Wales
# 669 2002-09-13  2002  Unprovoked  SOUTH AFRICA    Western Cape Province
# 670 1963-02-08  1963  Unprovoked          FIJI  Lomaiviti  Island Group
# 671 1960-04-24  1960  Unprovoked           USA               California
# 672 1936-02-04  1936  Unprovoked     AUSTRALIA          New South Wales
#
#                                               location  \
# 0                        Summerland Key, Monroe County
# 1    Deerfield Beach (near Boca Raton), Broward County
# 2                      Vero Beach, Indian River County
# 3                                          Compass Cay
# 4                        Biscayne National Park, Miami
# ..                                                 ...
# 668                                        Lennox Head
# 669                               Glencairn, False Bay
# 670                       Taibaisa Passage, Gau Island
# 671                        Tomales Point, Marin County
# 672                                South Steyne, Manly
#
#                                            activity                    name  \
# 0                                           Fishing                    male
# 1                                        Snorkeling             Robert Land
# 2                                           Surfing           Brad Milliken
# 3                                          Swimming             Asher Jones
# 4                                          Swimming        Carmen Dominguez
# ..                                              ...                     ...
# 668                                         Surfing           Michael Hoile
# 669                                     Surf skiing  Paul Mauger (or Major)
# 670                                    Spearfishing          Jone Waiteatei
# 671  Free diving for abalone diving but at surface)        Frank I. Gilbert
# 672                                        Swimming             David Paton
#
#     sex  age                                             injury fatal_y_n  \
# 0     M   23  Superficial injury to calf by hooked shark PRO...         N
# 1     M   39                                         Arm bitten         N
# 2     M   15         Lacerations on heel & dorsum of right foot         N
# 3     M    8                 Arc of shallow lacerations to back         N
# 4     F   43    Thigh injured by hooked shark PROVOKED INCIDENT         N
# ..   ..  ...                                                ...       ...
# 668   M   52                     No injury, shark bit surfboard         N
# 669   M   47                                          No injury         N
# 670   M   28                                    Left arm bitten         N
# 671   M   48                             Foot & swim fin bitten         N
# 672   M   14  FATAL, taken by shark, body not recovered. Twe...         Y
#
#        Species_1
# 0    Nurse shark
# 1    Nurse shark
# 2    Nurse shark
# 3    Nurse shark
# 4    Nurse shark
# ..           ...
# 668  White shark
# 669  White shark
# 670  White shark
# 671  White shark
# 672  White shark
#
# [673 rows x 13 columns]

# %%
activity_df = shark_clean_data_df[['activity']]

# %%
activity_df
# Out:
#                                            activity
# 0                                           Fishing
# 1                                        Snorkeling
# 2                                           Surfing
# 3                                          Swimming
# 4                                          Swimming
# ..                                              ...
# 668                                         Surfing
# 669                                     Surf skiing
# 670                                    Spearfishing
# 671  Free diving for abalone diving but at surface)
# 672                                        Swimming
#
# [673 rows x 1 columns]

# %%
activity_df.value_counts()
# Out:
# activity
# Surfing                                                                   195
# Swimming                                                                  107
# Spearfishing                                                               56
# Body boarding                                                              19
# Fishing                                                                    19
#                                                                          ...
# Free diving for abalone (surfacing)                                         1
# Free diving / spearfishing, from paddleboard & floating on the surface      1
# Free diving / spearfishing (resting on the surface)                         1
# Free diving / spearfishing                                                  1
# Windsurfing, but sitting on his board                                       1
# Name: count, Length: 143, dtype: int64

# %%
activity_df = activity_df = activity_df.replace({"Free diving for abalone (surfacing)": 'Spearfishing',
"Free diving / spearfishing, from paddleboard & floating on the surface": 'Spearfishing',
"Free diving / spearfishing (resting on the surface)":'Spearfishing',
"Free diving / spearfishing":'Spearfishing'})

# %%
activity_df.value_counts()
# Out:
# activity
# Surfing                                           195
# Swimming                                          107
# Spearfishing                                       60
# Body boarding                                      19
# Fishing                                            19
#                                                  ...
# Free diving with seals                              1
# Free diving or wading back to shore                 1
# Free diving for abalone diving but at surface)      1
# Free diving (but on surface)                        1
# Windsurfing, but sitting on his board               1
# Name: count, Length: 139, dtype: int64

# %%
activity_df = activity_df = activity_df.replace({"Free diving with seals ": 'Free Diving',
"Free diving or wading back to shore": 'Free Diving',
"Free diving for abalone diving but at surface)": 'Free Diving',
"Free diving (but on surface)":'Free Diving',
"Windsurfing, but sitting on his board":'Windsurfing'})

# %%
activity_df.value_counts()
# Out:
# activity
# Surfing                                                                                    195
# Swimming                                                                                   107
# Spearfishing                                                                                60
# Fishing                                                                                     19
# Body boarding                                                                               19
#                                                                                           ...
# Abalone diving using Hookah (near calving whales)                                            1
# Diving into water                                                                            1
# Picking opihi                                                                                1
# Paddling rescue ski                                                                          1
# 14 m prawn trawler New Venture capsized  & sank in heavy seas Three people in the water      1
# Name: count, Length: 136, dtype: int64

# %%
activity_df = activity_df = activity_df.replace({"Abalone diving using Hookah (near calving whales)": 'Other',
"Diving into water ": 'Free Diving',
"Picking opihi ": 'Other',
"Paddling rescue ski":'Other',
"14 m prawn trawler New Venture capsized  & sank in heavy seas Three people in the water":'Other'})

# %%
activity_df .value_counts()
# Out:
# activity
# Surfing                       195
# Swimming                      107
# Spearfishing                   60
# Fishing                        19
# Body boarding                  19
#                              ...
# Rolled off raft                 1
# Riding floatation device        1
# Bathing in knee-deep water      1
# Dog paddling or standing        1
# Playing in the water            1
# Name: count, Length: 134, dtype: int64

# %%
activity_df = activity_df = activity_df.replace({"Rolled off raft": 'Other',
"Riding floatation device": 'Other',
"Bathing in knee-deep water": 'Other',
"Dog paddling or standing":'Other',
"Playing in the water":'Other'})

# %%
activity_df.value_counts()
# Out:
# activity
# Surfing                                                                                  195
# Swimming                                                                                 107
# Spearfishing                                                                              60
# Body boarding                                                                             19
# Fishing                                                                                   19
#                                                                                         ...
# Diving, but on the surface when bitten by the shark                                        1
# Rowing                                                                                     1
# Dress diving, filming shark & pulling it through the water for a motion picture scene      1
# Fishing - 'tag & release'                                                                  1
# Spearfishing / free diving                                                                 1
# Name: count, Length: 129, dtype: int64

# %%
activity_df = activity_df = activity_df.replace({"Diving, but on the surface when bitten by the shark": 'Free Diving',
"Rowing": 'Other',
"Dress diving, filming shark & pulling it through the water for a motion picture scene": 'Other',
"Fishing - 'tag & release'":'Fishing',
"Spearfishing / free diving ":'Spearfishing'})

# %%
activity_df.value_counts()
# Out:
# activity
# Surfing                                                195
# Swimming                                               107
# Spearfishing                                            60
# Fishing                                                 20
# Body boarding                                           19
#                                                       ...
# Scallop diving (using surface-supplied air & a POD)      1
# Sailing on catamaran & fell into the water               1
# SUP Foil boarding                                        1
# Fishing / standing in waist deep water                   1
# Spearfishing, dived to pick up a float line              1
# Name: count, Length: 125, dtype: int64

# %%
activity_df = activity_df = activity_df.replace({"Scallop diving (using surface-supplied air & a POD)": 'Free Diving',
"Sailing on catamaran & fell into the water": 'Other',
"SUP Foil boarding": 'Other',
"Fishing / standing in waist deep water":'Fishing',
"Spearfishing, dived to pick up a float line":'Spearfishing'})

# %%
activity_df.value_counts()
# Out:
# activity
# Surfing                                                                    195
# Swimming                                                                   107
# Spearfishing                                                                61
# Fishing                                                                     21
# Body boarding                                                               19
#                                                                           ...
# Diving from the lugger San, operated by the Protector of the Aborigines      1
# Diving into water                                                            1
# Scallop diving on hookah                                                     1
# Fishing for sharks                                                           1
# Spearfishing, pulled shark’s tail                                            1
# Name: count, Length: 120, dtype: int64

# %%
activity_df = activity_df = activity_df.replace({"Diving into water": 'Free Diving',
"Scallop diving on hookah": 'Free Diving',
"Sailing": 'Other',
"Fishing for sharks":'Fishing',
"Spearfishing, holding mesh bag with speared fish":'Spearfishing'})

# %%
activity_df.value_counts()
# Out:
# activity
# Surfing                                                                    195
# Swimming                                                                   107
# Spearfishing                                                                62
# Fishing                                                                     22
# Body boarding                                                               19
#                                                                           ...
# Diving for trochus                                                           1
# Scuba diving & spearfishing                                                  1
# Diving from the lugger San, operated by the Protector of the Aborigines      1
# Fishing from a kayak                                                         1
# Diving for Abalone                                                           1
# Name: count, Length: 116, dtype: int64

# %%
activity_df = activity_df = activity_df.replace({"Diving for trochus": 'Free Diving',
"Scuba diving & spearfishing": 'Spearfishing',
"Diving from the lugger San, operated by the Protector of the Aborigines": 'Free Diving',
"Fishing from a kayak":'Fishing',
"Diving for Abalone":'Free Diving'})

# %%
activity_df.value_counts()
# Out:
# activity
# Surfing                                                             195
# Swimming                                                            107
# Spearfishing                                                         63
# Fishing                                                              23
# Body boarding                                                        19
#                                                                    ...
# Spearfishing, had fish on his spear                                   1
# Spearfishing, pulled shark’s tail                                     1
# Splashing                                                             1
# Dived overboard to check propeller of US Navy motor torpedo boat      1
# Standing / Snorkeling                                                 1
# Name: count, Length: 111, dtype: int64

# %%
activity_df = activity_df = activity_df.replace({"Spearfishing, pulled shark’s tail": 'Spearfishing',
"Spearfishing, had fish on his spear": 'Spearfishing',
"Splashing": 'Free Diving',
"Dived overboard to check propeller of US Navy motor torpedo boat":'Free Diving',
"Standing / Snorkeling":'Snorkeling'})

# %%
activity_df.value_counts()
# Out:
# activity
# Surfing                                                                                  195
# Swimming                                                                                 107
# Spearfishing                                                                              65
# Fishing                                                                                   23
# Body boarding                                                                             19
#                                                                                         ...
# Spearfishing / free diving                                                                 1
# Spearfishing with Scuba gear                                                               1
# Standing in waist-deep water, helping his father tend a gill net containing dead fish      1
# Kite Boarding                                                                              1
# Surf fishing in waist-deep water                                                           1
# Name: count, Length: 106, dtype: int64

# %%
activity_df = activity_df = activity_df.replace({"Spearfishing / free diving": 'Spearfishing',
"Spearfishing with Scuba gear": 'Spearfishing',
"Standing in waist-deep water, helping his father tend a gill net containing dead fish": 'Other',
"Surf fishing in waist-deep water ":'Fishing',
"Kite Boarding":'Other'})

# %%
activity_df.value_counts().tail(60)
# Out:
# activity
# Boogie Boarding                                                                                             2
# Swimming / Body Surfing                                                                                     1
# Swimming near pier                                                                                          1
# Body-boarding                                                                                               1
# Swimming breast stoke                                                                                       1
# Casting a net                                                                                               1
# Swimming /  boogie boarding                                                                                 1
# Surfing with dolphins                                                                                       1
# Surfing, paddling seawards                                                                                  1
# Surfing, lying on surfboard                                                                                 1
# Surfing, fell off surfboard & stepped on the shark.                                                         1
# Swimming or Snorkeling                                                                                      1
# Swimming underwater from crayfish cage to a fishing bait                                                    1
# Swimming with dolphins                                                                                      1
# Swimming with other crew near wharf                                                                         1
# Body surfing / treading water                                                                               1
# Swimming, naked                                                                                             1
# Swimming, poaching perlemoen                                                                                1
# Swimming. Passer-by, Len Bedford, heard him shriek , saw shark leap from the water & swimmer disappeared    1
# Teasing a shark                                                                                             1
# Thrashing the water / imitating the shark victim from Jaws                                                  1
# Body surfing & treading water                                                                               1
# Body boarding or surfing                                                                                    1
# Wading / fishing & carrying a bag of fish                                                                   1
# Wading in school of baitfish                                                                                1
# Body Surfing                                                                                                1
# Walking on reef                                                                                             1
# Water-skiing                                                                                                1
# Surfing, but treading water                                                                                 1
# Killing a shark                                                                                             1
# Surfing on air mattress                                                                                     1
# Cleaning fish                                                                                               1
# Kite surfing                                                                                                1
# Kiteboarding                                                                                                1
# Lifesaving drill                                                                                            1
# Lifesaving exhibition                                                                                       1
# Lying on surfboard                                                                                          1
# Lying prone in 2' of water                                                                                  1
# Night bathing                                                                                               1
# Kayak Fishing                                                                                               1
# Hand feeding sharks                                                                                         1
# Paddling                                                                                                    1
# Paddling on surfboard                                                                                       1
# Picking opihi                                                                                               1
# Free diving, Spearfishing                                                                                   1
# Free diving with seals                                                                                      1
# Free diving & spearfishing (ascending)                                                                      1
# Free diving & spearfishing                                                                                  1
# Floating on his back                                                                                        1
# Floating in inflatable pool ring                                                                            1
# Scuba diving (submerged riding a scooter)                                                                   1
# Shark fishing                                                                                               1
# Fishing with hand net in 2' of water                                                                        1
# Spearfishing (Free diving)                                                                                  1
# Diving for abaone (Scuba, but at surface)                                                                   1
# Diving for abalone (Scuba)                                                                                  1
# Diving for abalone (Hookah, submerged)                                                                      1
# Surf fishing in waist-deep water                                                                            1
# Collecting fish by lamplight in gully                                                                       1
# Cleaning hull of ship                                                                                       1
# Name: count, dtype: int64

# %%
activity_df = activity_df = activity_df.replace({
"Cleaning hull of ship": 'Other',
"Surf fishing in waist-deep water": 'Fishing',
"Diving for abalone (Hookah, submerged)": 'Free Diving',
"Diving for abalone (Scuba)":'Free Diving',
"Diving for abaone (Scuba, but at surface)":'Free Diving',
"Swimming / Body Surfing":"Swimming",
"Swimming near pier":"Swimming",
"Body-boarding":"Body boarding",
"Swimming breast stoke":"Swimming",
"Casting a net":"Other",
"Swimming /  boogie boarding":"Swimming",
"Surfing with dolphins":"Surfing",
"Surfing, paddling seawards":"Surfing",
"Surfing, lying on surfboard":"Surfing",
"Surfing, fell off surfboard & stepped on the shark.":"Surfing",
"Swimming or Snorkeling":"Swimming",
"Swimming underwater from crayfish cage to a fishing bait":"Swimming",
"Swimming with dolphins":"Swimming",
"Swimming with other crew near wharf":"Swimming",
"Body surfing / treading water":"Body boarding",
"Swimming, naked":"Swimming",
"Swimming, poaching perlemoen":"Swimming",
"Swimming. Passer-by, Len Bedford, heard him shriek , saw shark leap from the water & swimmer disappeared":"Swimming",
"Teasing a shark":"Other",
"Thrashing the water / imitating the shark victim from Jaws":"Other",
"Body surfing & treading water":"Body boarding",
"Body boarding or surfing":"Body boarding",
"Wading / fishing & carrying a bag of fish":"Other",
"Wading in school of baitfish":"Other",
"Body Surfing":"Body boarding",
"Walking on reef":"Other",                                                                                             
"Water-skiing":"Other",
"Surfing, but treading water":"Surfing",
"Killing a shark":"Other",
"Surfing on air mattress":"Other",
"Cleaning fish":"Other",
"Kite surfing":"Other",
"Kiteboarding":"Other",
"Lifesaving drill":"Other",
"Lifesaving exhibition":"Other",
"Lying on surfboard":"Other",
"Lying prone in 2' of water":"Other",
"Night bathing":"Other",
"Kayak Fishing":"Fishing",
"Hand feeding sharks":"Other",
"Paddling":"Other",
"Paddling on surfboard":"Other",
"Picking opihi":"Other",
"Free diving, Spearfishing":"Spearfishing",
"Free diving with seals":"Free Diving",
"Free diving & spearfishing (ascending)":"Spearfishing",
"Free diving & spearfishing":"Spearfishing",
"Floating on his back":"Other",
"Floating in inflatable pool ring": "Other",
"Scuba diving (submerged riding a scooter)":"Free Diving",                                                                   
"Shark fishing": "Fishing",
"Fishing with hand net in 2' of water": "Fishing",                                                                     
"Spearfishing (Free diving)": "Spearfishing"
})

# %%
activity_df.value_counts()
# Out:
# activity
# Surfing                                             200
# Swimming                                            118
# Spearfishing                                         71
# Other                                                38
# Fishing                                              27
# Body boarding                                        24
# Free Diving                                          17
# Snorkeling                                           16
# Standing                                             16
# Wading                                               16
# Kayaking                                             11
# Scuba diving                                         10
# Diving                                                9
# Body surfing                                          9
# Treading water                                        9
# Free diving                                           8
# Boogie boarding                                       7
# Surf-skiing                                           6
# Surf skiing                                           4
# Walking                                               4
# Free diving for abalone                               4
# Body Boarding                                         3
# Windsurfing                                           3
# Paddle boarding                                       3
# Stand-Up Paddleboarding                               3
# Swimming / snorkeling                                 2
# Spearfishing / Scuba diving (at surface)              2
# Swimming from the New Venture                         2
# Swimming, ducking for shells in water 0.9 m deep      2
# Bathing                                               2
# Spearfishing / Scuba diving                           2
# Spearfishing (free diving)                            2
# Scuba diving (but on surface)                         2
# Scuba Diving                                          2
# Playing in the surf                                   2
# Playing                                               2
# Kite Surfing                                          2
# Kayaking / Fishing                                    2
# Floating                                              2
# Diving for abalone (Hookah)                           2
# Diving for abalone                                    2
# Boogie Boarding                                       2
# SUP                                                   2
# Collecting fish by lamplight in gully                 1
# Name: count, dtype: int64

# %%
activity_df = activity_df = activity_df.replace({
"Scuba diving":"Free Diving",
"Diving":"Free Diving",
"Body surfing":"Body Boarding",
"Treading water":"Swimming",
"Free diving":"Free Diving",
"Boogie boarding":"Body Boarding",
"Surf-skiing":"Other",
"Surf skiing":"Other",
"Walking":"Other",
"Free diving for abalone":"Free Diving",
"Body Boarding":"Body Boarding",
"Windsurfing":"Windsurfing",
"Paddle boarding":"Other",
"Stand-Up Paddleboarding":"Other",
"Swimming / snorkeling":"Swimming",
"Spearfishing / Scuba diving (at surface)":"Spearfishing",
"Swimming from the New Venture":"Swimming",
"Swimming, ducking for shells in water 0.9 m deep":"Swimming",
"Bathing":"Other",
"Spearfishing / Scuba diving":"Spearfishing",
"Spearfishing (free diving)":"Spearfishing",
"Scuba diving (but on surface)":"Free Diving",
"Scuba Diving":"Free Diving",
"Playing in the surf":"Other",
"Playing":"Other",
"Kite Surfing":"Other",
"Kayaking / Fishing":"Kayaking",
"Floating":"Other",
"Diving for abalone (Hookah)":"Free Diving",
"Diving for abalone":"Free Diving",
"Boogie Boarding":"Body Boarding",
"SUP":"Other",          
"Collecting fish by lamplight in gully":"Fishing"               
})

# %%
activity_df.value_counts()
# Out:
# activity
# Surfing          200
# Swimming         133
# Spearfishing      77
# Other             70
# Free Diving       56
# Fishing           28
# Body boarding     24
# Body Boarding     21
# Snorkeling        16
# Standing          16
# Wading            16
# Kayaking          13
# Windsurfing        3
# Name: count, dtype: int64

# %%
activity_df = activity_df = activity_df.replace({"Body boarding":"Body Boarding"})

# %%
activity_df.value_counts()
# Out:
# activity
# Surfing          200
# Swimming         133
# Spearfishing      77
# Other             70
# Free Diving       56
# Body Boarding     45
# Fishing           28
# Snorkeling        16
# Standing          16
# Wading            16
# Kayaking          13
# Windsurfing        3
# Name: count, dtype: int64

# %%
activity_list = ['Surfing','Swimming','Spearfishing','Other','Free Diving','Body Boarding','Fishing','Snorkeling','Standing',
'Wading','Kayaking','Windsurfing']
attack_number_list = [200,133,77,70,56,45,28,16,16,16,13,3]

# %%
plt.bar(activity_list,attack_number_list)
plt.xticks(activity_list, rotation="vertical")
plt.xlabel("Activity")
plt.ylabel("Number of Shark Attacks")
plt.title("Number of Shark Attacks by Activity")
plt.tight_layout()

# %%
activity_type_df = shark_clean_data_df[['type','activity']]
activity_type_df = activity_type_df.replace(to_replace='Watercraft', value=np.nan).dropna()
activity_type_df.value_counts()
# Out:
# type        activity
# Unprovoked  Surfing                                      189
#             Swimming                                     103
#             Spearfishing                                  49
#             Body boarding                                 19
#             Standing                                      16
#                                                         ...
#             Diving for trochus                             1
#             Diving for abaone (Scuba, but at surface)      1
#             Diving for abalone (Scuba)                     1
#             Diving for abalone (Hookah, submerged)         1
#             Windsurfing, but sitting on his board          1
# Name: count, Length: 156, dtype: int64

# %%
activity_type_df = activity_type_df.replace(to_replace='Invalid', value=np.nan).dropna()
activity_type_df
# Out:
#            type                                        activity
# 0      Provoked                                         Fishing
# 1    Unprovoked                                      Snorkeling
# 2    Unprovoked                                         Surfing
# 3    Unprovoked                                        Swimming
# 4      Provoked                                        Swimming
# ..          ...                                             ...
# 668  Unprovoked                                         Surfing
# 669  Unprovoked                                     Surf skiing
# 670  Unprovoked                                    Spearfishing
# 671  Unprovoked  Free diving for abalone diving but at surface)
# 672  Unprovoked                                        Swimming
#
# [641 rows x 2 columns]

# %%
revised_activity_type_df = activity_type_df.set_index(['activity'])
value_counts_df = revised_activity_type_df.loc['Surfing'].value_counts()
index = ['Unprovoked', 'Provoked']
value_counts_df.plot(kind='pie',x='type',labels = index,autopct = "%1.1f%%",startangle= 200)
plt.title('Surfing Deep Dive: Provoked v. Unprovoked')
plt.axis("equal")
plt.legend()

# %%
value_counts = activity_df.value_counts()
value_counts_df = pd.DataFrame({"Number of Attacks":value_counts})
